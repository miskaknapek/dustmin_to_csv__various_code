# %%
import pandas as pd
import numpy as np
import time

# %%
one = pd.Timestamp( time.ctime() )

# %%
one
# Out:
# Timestamp('2019-01-16 13:32:03')

# %%
dir( time )
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'clock',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'perf_counter',
#  'process_time',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'time',
#  'timezone',
#  'tzname',
#  'tzset']

# %%
time.ctime()
# Out:
# 'Wed Jan 16 13:32:04 2019'

# %%
pd.Timedelta( '1 days')
# Out:
# Timedelta('1 days 00:00:00')

# %%
pd.Timedelta( days=1, seconds=1 )
# Out:
# Timedelta('1 days 00:00:01')

# %%
pd.Timedelta( np.timedelta64( 1, 'ms'))
# Out:
# Timedelta('0 days 00:00:00.001000')

# %%
daterange = pd.date_range( time.ctime(), periods=24, freq='H')

# %%
daterange
# Out:
# DatetimeIndex(['2019-01-16 13:32:04', '2019-01-16 14:32:04',
#                '2019-01-16 15:32:04', '2019-01-16 16:32:04',
#                '2019-01-16 17:32:04', '2019-01-16 18:32:04',
#                '2019-01-16 19:32:04', '2019-01-16 20:32:04',
#                '2019-01-16 21:32:04', '2019-01-16 22:32:04',
#                '2019-01-16 23:32:04', '2019-01-17 00:32:04',
#                '2019-01-17 01:32:04', '2019-01-17 02:32:04',
#                '2019-01-17 03:32:04', '2019-01-17 04:32:04',
#                '2019-01-17 05:32:04', '2019-01-17 06:32:04',
#                '2019-01-17 07:32:04', '2019-01-17 08:32:04',
#                '2019-01-17 09:32:04', '2019-01-17 10:32:04',
#                '2019-01-17 11:32:04', '2019-01-17 12:32:04'],
#               dtype='datetime64[ns]', freq='H')

# %%
# move back one day… 
daterange - pd.Timedelta( days=1 )
# Out:
# DatetimeIndex(['2019-01-15 13:32:04', '2019-01-15 14:32:04',
#                '2019-01-15 15:32:04', '2019-01-15 16:32:04',
#                '2019-01-15 17:32:04', '2019-01-15 18:32:04',
#                '2019-01-15 19:32:04', '2019-01-15 20:32:04',
#                '2019-01-15 21:32:04', '2019-01-15 22:32:04',
#                '2019-01-15 23:32:04', '2019-01-16 00:32:04',
#                '2019-01-16 01:32:04', '2019-01-16 02:32:04',
#                '2019-01-16 03:32:04', '2019-01-16 04:32:04',
#                '2019-01-16 05:32:04', '2019-01-16 06:32:04',
#                '2019-01-16 07:32:04', '2019-01-16 08:32:04',
#                '2019-01-16 09:32:04', '2019-01-16 10:32:04',
#                '2019-01-16 11:32:04', '2019-01-16 12:32:04'],
#               dtype='datetime64[ns]', freq='H')

# %%
# move back a dew hours… 
daterange - pd.Timedelta( hours=1 )
# Out:
# DatetimeIndex(['2019-01-16 12:32:04', '2019-01-16 13:32:04',
#                '2019-01-16 14:32:04', '2019-01-16 15:32:04',
#                '2019-01-16 16:32:04', '2019-01-16 17:32:04',
#                '2019-01-16 18:32:04', '2019-01-16 19:32:04',
#                '2019-01-16 20:32:04', '2019-01-16 21:32:04',
#                '2019-01-16 22:32:04', '2019-01-16 23:32:04',
#                '2019-01-17 00:32:04', '2019-01-17 01:32:04',
#                '2019-01-17 02:32:04', '2019-01-17 03:32:04',
#                '2019-01-17 04:32:04', '2019-01-17 05:32:04',
#                '2019-01-17 06:32:04', '2019-01-17 07:32:04',
#                '2019-01-17 08:32:04', '2019-01-17 09:32:04',
#                '2019-01-17 10:32:04', '2019-01-17 11:32:04'],
#               dtype='datetime64[ns]', freq='H')

# %%
# try make a time range, back in time, based on variables
hours_ = 24

# %%
original_time_range = pd.date_range( time.ctime(), periods=hours_, freq="H")
original_time_range
# Out:
# DatetimeIndex(['2019-01-16 13:32:05', '2019-01-16 14:32:05',
#                '2019-01-16 15:32:05', '2019-01-16 16:32:05',
#                '2019-01-16 17:32:05', '2019-01-16 18:32:05',
#                '2019-01-16 19:32:05', '2019-01-16 20:32:05',
#                '2019-01-16 21:32:05', '2019-01-16 22:32:05',
#                '2019-01-16 23:32:05', '2019-01-17 00:32:05',
#                '2019-01-17 01:32:05', '2019-01-17 02:32:05',
#                '2019-01-17 03:32:05', '2019-01-17 04:32:05',
#                '2019-01-17 05:32:05', '2019-01-17 06:32:05',
#                '2019-01-17 07:32:05', '2019-01-17 08:32:05',
#                '2019-01-17 09:32:05', '2019-01-17 10:32:05',
#                '2019-01-17 11:32:05', '2019-01-17 12:32:05'],
#               dtype='datetime64[ns]', freq='H')

# %%
date_range_moved = original_time_range - pd.Timedelta( hours=hours_ ) 
date_range_moved
# Out:
# DatetimeIndex(['2019-01-15 13:32:05', '2019-01-15 14:32:05',
#                '2019-01-15 15:32:05', '2019-01-15 16:32:05',
#                '2019-01-15 17:32:05', '2019-01-15 18:32:05',
#                '2019-01-15 19:32:05', '2019-01-15 20:32:05',
#                '2019-01-15 21:32:05', '2019-01-15 22:32:05',
#                '2019-01-15 23:32:05', '2019-01-16 00:32:05',
#                '2019-01-16 01:32:05', '2019-01-16 02:32:05',
#                '2019-01-16 03:32:05', '2019-01-16 04:32:05',
#                '2019-01-16 05:32:05', '2019-01-16 06:32:05',
#                '2019-01-16 07:32:05', '2019-01-16 08:32:05',
#                '2019-01-16 09:32:05', '2019-01-16 10:32:05',
#                '2019-01-16 11:32:05', '2019-01-16 12:32:05'],
#               dtype='datetime64[ns]', freq='H')

# %%
date_range_moved_as_epoc = date_range_moved.astype( np.int32 )
date_range_moved_as_epoc
# Out:
# Int64Index([1547559125000000000, 1547562725000000000, 1547566325000000000,
#             1547569925000000000, 1547573525000000000, 1547577125000000000,
#             1547580725000000000, 1547584325000000000, 1547587925000000000,
#             1547591525000000000, 1547595125000000000, 1547598725000000000,
#             1547602325000000000, 1547605925000000000, 1547609525000000000,
#             1547613125000000000, 1547616725000000000, 1547620325000000000,
#             1547623925000000000, 1547627525000000000, 1547631125000000000,
#             1547634725000000000, 1547638325000000000, 1547641925000000000],
#            dtype='int64')

# %%
date_range_moved.shape
# Out:
# (24,)

# %%
date_range_moved[0]
# Out:
# Timestamp('2019-01-15 13:32:05', freq='H')

# %%
dir( date_range_moved[0] )
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_date_attributes',
#  '_date_repr',
#  '_get_date_name_field',
#  '_get_start_end_field',
#  '_has_time_component',
#  '_repr_base',
#  '_round',
#  '_short_repr',
#  '_time_repr',
#  'asm8',
#  'astimezone',
#  'ceil',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'day_name',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'dst',
#  'floor',
#  'fold',
#  'freq',
#  'freqstr',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'is_leap_year',
#  'is_month_end',
#  'is_month_start',
#  'is_quarter_end',
#  'is_quarter_start',
#  'is_year_end',
#  'is_year_start',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'month_name',
#  'nanosecond',
#  'normalize',
#  'now',
#  'quarter',
#  'replace',
#  'resolution',
#  'round',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'to_datetime64',
#  'to_julian_date',
#  'to_period',
#  'to_pydatetime',
#  'today',
#  'toordinal',
#  'tz',
#  'tz_convert',
#  'tz_localize',
#  'tzinfo',
#  'tzname',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'value',
#  'week',
#  'weekday',
#  'weekday_name',
#  'weekofyear',
#  'year']

# %%
 date_range_moved[0].ctime()
# Out:
# 'Tue Jan 15 13:32:05 2019'

# %%
 date_range_moved[0].timestamp()
# Out:
# 1547559125.0

# %%
str( date_range_moved[0] )
# Out:
# '2019-01-15 13:32:05'

# %%
start_time = time.time()
start_time

time.sleep( 1 )
time_1_sec_later = time.time()

# %%
time_diff = time_1_sec_later - start_time
time_diff
# Out:
# 1.0046119689941406

# %%
# another go with getting the right time range
# - we start with the time range
daterange2 = pd.date_range( time.ctime(), periods=24, freq='H')
daterange2
# Out:
# DatetimeIndex(['2019-01-16 13:32:11', '2019-01-16 14:32:11',
#                '2019-01-16 15:32:11', '2019-01-16 16:32:11',
#                '2019-01-16 17:32:11', '2019-01-16 18:32:11',
#                '2019-01-16 19:32:11', '2019-01-16 20:32:11',
#                '2019-01-16 21:32:11', '2019-01-16 22:32:11',
#                '2019-01-16 23:32:11', '2019-01-17 00:32:11',
#                '2019-01-17 01:32:11', '2019-01-17 02:32:11',
#                '2019-01-17 03:32:11', '2019-01-17 04:32:11',
#                '2019-01-17 05:32:11', '2019-01-17 06:32:11',
#                '2019-01-17 07:32:11', '2019-01-17 08:32:11',
#                '2019-01-17 09:32:11', '2019-01-17 10:32:11',
#                '2019-01-17 11:32:11', '2019-01-17 12:32:11'],
#               dtype='datetime64[ns]', freq='H')

# %%
# we subtract the period frequency we originally set
daterange_minus_24_hours = daterange2 - 24
daterange_minus_24_hours
# Out:
# DatetimeIndex(['2019-01-15 13:32:11', '2019-01-15 14:32:11',
#                '2019-01-15 15:32:11', '2019-01-15 16:32:11',
#                '2019-01-15 17:32:11', '2019-01-15 18:32:11',
#                '2019-01-15 19:32:11', '2019-01-15 20:32:11',
#                '2019-01-15 21:32:11', '2019-01-15 22:32:11',
#                '2019-01-15 23:32:11', '2019-01-16 00:32:11',
#                '2019-01-16 01:32:11', '2019-01-16 02:32:11',
#                '2019-01-16 03:32:11', '2019-01-16 04:32:11',
#                '2019-01-16 05:32:11', '2019-01-16 06:32:11',
#                '2019-01-16 07:32:11', '2019-01-16 08:32:11',
#                '2019-01-16 09:32:11', '2019-01-16 10:32:11',
#                '2019-01-16 11:32:11', '2019-01-16 12:32:11'],
#               dtype='datetime64[ns]', freq='H')

# %%
# and then, just for practice, turn it into epoch 
daterange_minus_24_hours__as_epoc = daterange_minus_24_hours.astype( np.int32 )
daterange_minus_24_hours__as_epoc
# Out:
# Int64Index([1547559131000000000, 1547562731000000000, 1547566331000000000,
#             1547569931000000000, 1547573531000000000, 1547577131000000000,
#             1547580731000000000, 1547584331000000000, 1547587931000000000,
#             1547591531000000000, 1547595131000000000, 1547598731000000000,
#             1547602331000000000, 1547605931000000000, 1547609531000000000,
#             1547613131000000000, 1547616731000000000, 1547620331000000000,
#             1547623931000000000, 1547627531000000000, 1547631131000000000,
#             1547634731000000000, 1547638331000000000, 1547641931000000000],
#            dtype='int64')

# %%
type( daterange_minus_24_hours__as_epoc[0] )
# Out:
# numpy.int64

# %%
single_daterange_as_epoch__value = daterange_minus_24_hours__as_epoc[0]

# %%
# try convert the timestamp in the data, to epoch

in_data = pd.read_csv( "/Users/miska/Documents/open_something/luftdaten/luftdaten_code/luftdaten__make_tabular_data__from_db_data/ld_NYE_midnight_24hrs_nordics_all_data_01.csv" )

# %%
in_data.dtypes
# Out:
# sensor_id         int64
# sensor_namee     object
# lat             float64
# lon             float64
# timestamp        object
# p1              float64
# p2              float64
# dtype: object

# %%
in_data['timestamp'] = pd.to_datetime( in_data['timestamp'] )

# %%
in_data.dtypes
# Out:
# sensor_id                int64
# sensor_namee            object
# lat                    float64
# lon                    float64
# timestamp       datetime64[ns]
# p1                     float64
# p2                     float64
# dtype: object

# %%
in_data
# Out:
#         sensor_id sensor_namee     lat     lon           timestamp      p1  \
# 0            7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43
# 1            7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77
# 2            7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48
# 3            7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05
# 4            7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78
# 5            7469       SDS011  56.944  24.142 2018-12-31 11:57:52    8.40
# 6            7597       SDS011  59.320  18.064 2018-12-31 11:58:51    3.68
# 7            8683       SDS011  59.744  18.206 2018-12-31 11:58:28    3.01
# 8            9411       SDS011  59.266  15.230 2018-12-31 11:57:18    3.44
# 9            9436       SDS011  59.334  18.034 2018-12-31 11:57:22    2.12
# 10           9743       SDS011  57.664  12.054 2018-12-31 11:57:15  268.58
# 11           9797       SDS011  57.492  12.652 2018-12-31 11:58:52   10.13
# 12          10216       SDS011  59.674  16.838 2018-12-31 11:57:28    3.94
# 13          10250       SDS011  58.692  12.478 2018-12-31 11:58:38   11.55
# 14          10281       SDS011  59.472  18.048 2018-12-31 11:58:42    5.18
# 15          10430       SDS011  59.958  17.726 2018-12-31 11:57:35    2.42
# 16          10647       SDS011  55.608  13.036 2018-12-31 11:58:28   14.65
# 17          10721       SDS011  59.450  18.124 2018-12-31 11:57:54    2.28
# 18          10723       SDS011  59.298  18.052 2018-12-31 11:56:45    4.90
# 19          10803       SDS011  57.690  11.954 2018-12-31 11:58:07   31.01
# 20          10823       SDS011  59.332  18.034 2018-12-31 11:57:37    3.78
# 21          10825       SDS011  55.898  14.094 2018-12-31 11:57:55    9.50
# 22          10827       SDS011  59.334  13.512 2018-12-31 11:56:40   11.45
# 23          10843       SDS011  59.354  18.364 2018-12-31 11:58:46    5.44
# 24          10914       SDS011  61.450  23.858 2018-12-31 11:58:48    1.97
# 25          10922       SDS011  59.494  17.976 2018-12-31 11:57:26    5.75
# 26          10924       SDS011  59.860  17.652 2018-12-31 11:56:44    2.58
# 27          10926       SDS011  59.472  18.304 2018-12-31 11:57:06    3.26
# 28          11002       SDS011  55.796  13.090 2018-12-31 11:58:37    6.34
# 29          11004       SDS011  59.622  16.556 2018-12-31 11:58:53    4.40
# ...           ...          ...     ...     ...                 ...     ...
# 127079      18826       SDS011  63.404  13.016 2019-01-01 11:59:35   11.82
# 127080      18836       SDS011  63.404  13.030 2019-01-01 11:59:39   12.26
# 127081      19119       SDS011  56.972  24.132 2019-01-01 11:56:
# ...           ...          ...     ...     ...                  ...     ...
# 127079      18826       SDS011  63.404  13.016  1546343975000000000   11.82
# 127080      18836       SDS011  63.404  13.030  1546343979000000000   12.26
# 127081      19119       SDS011  56.972  24.132  1546343793000000000   10.84
# 127082      19207       SDS011  59.466  18.036  1546343900000000000    5.74
# 127083      19301       SDS011  59.362  12.152  1546343810000000000    0.02
# 127084       7273       SDS011  60.002  17.846  1546343974000000000    2.63
# 127085      11232       SDS011  55.596  13.022  1546343986000000000   16.80
# 127086      11374       SDS011  59.258  18.008  1546343980000000000    6.35
# 127087      11378       SDS011  59.392  16.748  1546343987000000000    1.25
# 127088      11445       SDS011  64.178  15.432  1546343991000000000    0.45
# 127089      11546       SDS011  59.456  17.802  1546343985000000000    1.42
# 127090      11663       SDS011  59.380  18.040  1546343988000000000    1.77
# 127091      11769       SDS011  59.238  18.226  1546343996000000000    2.49
# 127092      12383       SDS011  63.808  20.336  1546343980000000000    2.13
# 127093      12387       SDS011  58.560  15.306  1546343992000000000    1.10
# 127094      12673       SDS011  59.364  18.022  1546343989000000000    2.63
# 127095      12675       SDS011  59.450  17.892  1546343987000000000    3.30
# 127096      12691       SDS011  57.636  18.304  1546343995000000000    5.25
# 127097      12990       SDS011  57.692  11.958  1546343880000000000   16.63
# 127098      13012       SDS011  57.662  12.006  1546343998000000000    8.18
# 127099      13020       SDS011  57.722  11.948  1546343981000000000   20.64
# 127100      16147       SDS011  59.364  18.018  1546343986000000000    3.28
# 127101      16153       SDS011  55.648  13.208  1546343839000000000   20.00
# 127102      16296       SDS011  56.144  13.394  1546343999000000000   23.86
# 127103      16533       SDS011  55.722  13.202  1546343815000000000   18.05
# 127104      16723       SDS011  57.736  11.894  1546343937000000000   16.47
# 127105      16815       SDS011  59.462  18.040  1546343976000000000    2.67
# 127106      17235       SDS011  59.272  17.780  1546343981000000000    4.69
# 127107      10588       SDS011  55.676  13.346  1546343832000000000   14.08
# 127108      10647       SDS011  55.608  13.036  1546343922000000000   23.42
#
#            p2
# 0        1.56
# 1       33.82
# 2        2.47
# 3        6.62
# 4        1.02
# 5        5.54
# 6        2.00
# 7        2.80
# 8        2.18
# 9        1.90
# 10      29.05
# 11       7.05
# 12       2.75
# 13       5.88
# 14       3.12
# 15       1.58
# 16       5.10
# 17       1.45
# 18       2.76
# 19       6.02
# 20       2.05
# 21       7.00
# 22       6.00
# 23       2.13
# 24       1.88
# 25       3.05
# 26       1.16
# 27       2.35
# 28       3.08
# 29       1.95
# ...       ...
# 127079   1.67
# 127080   1.97
# 127081   3.66
# 127082   2.40
# 127083   0.00
# 127084   1.30
# 127085   4.07
# 127086   4.08
# 127087   0.64
# 127088   0.26
# 127089   0.86
# 127090   1.10
# 127091   1.35
# 127092   0.65
# 127093   0.65
# 127094   1.50
# 127095   1.52
# 127096   1.94
# 127097   3.60
# 127098   2.25
# 127099   3.67
# 127100   1.80
# 127101   3.90
# 127102   7.45
# 127103   4.33
# 127104   3.40
# 127105   1.97
# 127106   1.82
# 127107   3.68
# 127108   4.75
#
# [127109 rows x 7 columns]

# %%
type( in_data_as_epoch['timestamp'][0] )
# Out:
# numpy.int64

# %%
single_timestamp_value_as_epoch__value = in_data_as_epoch['timestamp'][0]

# %%
# both values 
single_daterange_as_epoch__value, single_timestamp_value_as_epoch__value
# Out:
# (1547559131000000000, 1546257442000000000)

# %%
( single_timestamp_value_as_epoch__value - single_daterange_as_epoch__value ) / ( 60*60*24 * 1000000000
                                                                                )
# Out:
# -15.065844907407408

# %%
len( str( single_daterange_as_epoch__value )), len( str( single_timestamp_value_as_epoch__value ))
# Out:
# (19, 19)

# %%
# divide by a billion to get the time value in seconds ; ) 
time.ctime( single_daterange_as_epoch__value/1000000000 )
# Out:
# 'Tue Jan 15 14:32:11 2019'

# %%
# dry run

# %%
start_time = "2018-12-31 11:58:42"
end_time = "2019-01-01 11:58:42"

# %%
# set up the relevant time range

# %%
time_frequency = "5T"
num_of_time_periods = 24*12+1

# %%
time_date_range = pd.date_range( end_time, periods=num_of_time_periods, freq = time_frequency ) 
time_date_range = time_date_range - ( num_of_time_periods -1 )
time_date_range
# Out:
# DatetimeIndex(['2018-12-31 11:58:42', '2018-12-31 12:03:42',
#                '2018-12-31 12:08:42', '2018-12-31 12:13:42',
#                '2018-12-31 12:18:42', '2018-12-31 12:23:42',
#                '2018-12-31 12:28:42', '2018-12-31 12:33:42',
#                '2018-12-31 12:38:42', '2018-12-31 12:43:42',
#                ...
#                '2019-01-01 11:13:42', '2019-01-01 11:18:42',
#                '2019-01-01 11:23:42', '2019-01-01 11:28:42',
#                '2019-01-01 11:33:42', '2019-01-01 11:38:42',
#                '2019-01-01 11:43:42', '2019-01-01 11:48:42',
#                '2019-01-01 11:53:42', '2019-01-01 11:58:42'],
#               dtype='datetime64[ns]', length=289, freq='5T')

# %%
time_date_range_as_epoch = time_date_range.astype( np.int64 )
time_date_range_as_epoch
# Out:
# Int64Index([1546257522000000000, 1546257822000000000, 1546258122000000000,
#             1546258422000000000, 1546258722000000000, 1546259022000000000,
#             1546259322000000000, 1546259622000000000, 1546259922000000000,
#             1546260222000000000,
#             ...
#             1546341222000000000, 1546341522000000000, 1546341822000000000,
#             1546342122000000000, 1546342422000000000, 1546342722000000000,
#             1546343022000000000, 1546343322000000000, 1546343622000000000,
#             1546343922000000000],
#            dtype='int64', length=289)

# %%
# work with the in data 
in_data
# Out:
#         sensor_id sensor_namee     lat     lon            timestamp      p1  \
# 0            7273       SDS011  60.002  17.846  1546257442000000000    3.43
# 1            7275       SDS011  57.720  11.888  1546257524000000000  482.77
# 2            7277       SDS011  59.266  15.230  1546257527000000000    5.48
# 3            7406       SDS011  56.964  24.128  1546257401000000000   11.05
# 4            7428       SDS011  59.868  17.624  1546257462000000000    1.78
# 5            7469       SDS011  56.944  24.142  1546257472000000000    8.40
# 6            7597       SDS011  59.320  18.064  1546257531000000000    3.68
# 7            8683       SDS011  59.744  18.206  1546257508000000000    3.01
# 8            9411       SDS011  59.266  15.230  1546257438000000000    3.44
# 9            9436       SDS011  59.334  18.034  1546257442000000000    2.12
# 10           9743       SDS011  57.664  12.054  1546257435000000000  268.58
# 11           9797       SDS011  57.492  12.652  1546257532000000000   10.13
# 12          10216       SDS011  59.674  16.838  1546257448000000000    3.94
# 13          10250       SDS011  58.692  12.478  1546257518000000000   11.55
# 14          10281       SDS011  59.472  18.048  1546257522000000000    5.18
# 15          10430       SDS011  59.958  17.726  1546257455000000000    2.42
# 16          10647       SDS011  55.608  13.036  1546257508000000000   14.65
# 17          10721       SDS011  59.450  18.124  1546257474000000000    2.28
# 18          10723       SDS011  59.298  18.052  1546257405000000000    4.90
# 19          10803       SDS011  57.690  11.954  1546257487000000000   31.01
# 20          10823       SDS011  59.332  18.034  1546257457000000000    3.78
# 21          10825       SDS011  55.898  14.094  1546257475000000000    9.50
# 22          10827       SDS011  59.334  13.512  1546257400000000000   11.45
# 23          10843       SDS011  59.354  18.364  1546257526000000000    5.44
# 24          10914       SDS011  61.450  23.858  1546257528000000000    1.97
# 25          10922       SDS011  59.494  17.976  1546257446000000000    5.75
# 26          10924       SDS011  59.860  17.652  1546257404000000000    2.58
# 27          10926       SDS011  59.472  18.304  1546257426000000000    3.26
# 28          11002       SDS011  55.796  13.090  1546257517000000000    6.34
# 29          11004       SDS011  59.622  16.556  1546257533000000000    4.40
# 127081   3.66
# 127082   2.40
# 127083   0.00
# 127097   3.60
# 127101   3.90
# 127103   4.33
# 127107   3.68
#
# [48799 rows x 7 columns]

# %%
relevant_period.index
# Out:
# Int64Index([ 78090,  78094,  78095,  78109,  78122,  78129,  78132,  78134,
#              78136,  78146,
#             ...
#             127057, 127058, 127067, 127081, 127082, 127083, 127097, 127101,
#             127103, 127107],
#            dtype='int64', length=48799)

# %%
# create an array to store the results in 
out_array = np.zeros( time_date_range_as_epoch.shape[0] )

# %%
out_array.shape
# Out:
# (289,)

# %%
# create an array of values for the given sensor, 
# filling in possible blank areas with zeros ( well, by not adding anything there )

# %%
startime = time.time()
out = []
for row_i in range( relevant_period.shape[0] ):
    relev_time = int( relevant_period.loc[ row_i ]['timestamp'] ) 
#     print( type( relev_time ))
#     print( relev_time.shape )
#     out_array[row_i] = relev_time
    
print( "--- well, that took "+str( time.time() - start_time ) )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [0] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-207-fbab0fa8a925> in <module>
#       2 out = []
#       3 for row_i in range( relevant_period.shape[0] ):
# ----> 4     relev_time = int( relevant_period.loc[ row_i ]['timestamp'] )
#       5 #     print( type( relev_time ))
#       6 #     print( relev_time.shape )
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [0] is not in the [index]'

# %%
relevant_period[0:1].shape
# Out:
# (1, 7)

# %%
two = relevant_period[0:1]['timestamp']
two
# Out:
# 78090    1546293529000000000
# Name: timestamp, dtype: int64

# %%
relevant_period.loc[[2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-185-7bfb59424bcf> in <module>
# ----> 1 relevant_period.loc[[2]]
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1141             if labels.is_unique and Index(keyarr).is_unique:
#    1142                 indexer = ax.get_indexer_for(key)
# -> 1143                 self._validate_read_indexer(key, indexer, axis)
#    1144
#    1145                 d = {axis: [ax.reindex(keyarr)[0], indexer]}
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1204                 raise KeyError(
#    1205                     u"None of [{key}] are in the [{axis}]".format(
# -> 1206                         key=key, axis=self.obj._get_axis_name(axis)))
#    1207
#    1208             # we skip the warning on Categorical/Interval
#
# KeyError: 'None of [[2]] are in the [index]'

# %%
relevant_period.loc[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [3] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-186-75a3194dccbc> in <module>
# ----> 1 relevant_period.loc[3]
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [3] is not in the [index]'

# %%
relevant_period[0:1]
# Out:
#        sensor_id sensor_namee     lat    lon            timestamp     p1    p2
# 78090       7277       SDS011  59.266  15.23  1546293529000000000  11.11  3.52

# %%
relevant_period[1:2]
# Out:
#        sensor_id sensor_namee     lat     lon            timestamp     p1  \
# 78094       7499       SDS011  59.924  10.738  1546293541000000000  17.81
#
#          p2
# 78094  4.43

# %%
relevant_period.at[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-55d3f6940aee> in <module>
# ----> 1 relevant_period.at[0]
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2140
#    2141         key = self._convert_key(key)
# -> 2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#    2144     def __setitem__(self, key, value):
#
# TypeError: _get_value() missing 1 required positional argument: 'col'

# %%
relevant_period[:20]
# Out:
#        sensor_id sensor_namee     lat     lon            timestamp     p1  \
# 78090       7277       SDS011  59.266  15.230  1546293529000000000  11.11
# 78094       7499       SDS011  59.924  10.738  1546293541000000000  17.81
# 78095       7597       SDS011  59.320  18.064  1546293531000000000  75.32
# 78109      11380       SDS011  55.606  12.998  1546293536000000000  11.02
# 78122      11763       SDS011  56.522  14.950  1546293534000000000   5.78
# 78129      12385       SDS011  57.634  18.310  1546293524000000000   6.73
# 78132      12391       SDS011  59.860  17.640  1546293534000000000   7.41
# 78134      12120       SDS011  59.460  17.908  1546293529000000000  17.26
# 78136      12127       SDS011  57.702  11.904  1546293524000000000   6.85
# 78146      12691       SDS011  57.636  18.304  1546293540000000000   3.81
# 78148      12861       SDS011  66.348  14.134  1546293526000000000  12.69
# 78159      14209       SDS011  56.070  12.698  1546293541000000000  14.72
# 78174      16531       SDS011  57.698  11.958  1546293540000000000   5.33
# 78179      16723       SDS011  57.736  11.894  1546293535000000000  34.88
# 78180      13419       SDS011  58.440  15.470  1546293530000000000   6.28
# 78187      13475       SDS011  63.824  20.288  1546293534000000000   3.08
# 78195      14807       SDS011  57.718  12.034  1546293532000000000  22.82
# 78212      16296       SDS011  56.144  13.394  1546293535000000000  13.27
# 78215      18243       SDS011  55.674  13.072  1546293537000000000  15.98
# 78220      17038       SDS011  55.750  13.202  1546293530000000000  21.09
#
#           p2
# 78090   3.52
# 78094   4.43
# 78095  39.88
# 78109   3.71
# 78122   2.53
# 78129   4.57
# 78132   3.33
# 78134   8.48
# 78136   2.56
# 78146   2.45
# 78148   5.69
# 78159   4.65
# 78174   2.85
# 78179   5.66
# 78180   2.39
# 78187   0.98
# 78195   5.74
# 78212   5.37
# 78215   5.65
# 78220   8.81

# %%
one = int( relevant_period[20:21]['p1'] )

# %%
one
# Out:
# 25

# %%
relevant_period[20:21]['timestamp']
# Out:
# 78233    1546293541000000000
# Name: timestamp, dtype: int64

# %%
float( relevant_period[20:21]['p1'] )
# Out:
# 25.19

# %%
type( relevant_period['timestamp'] )
# Out:
# pandas.core.series.Series

# %%
relevant_period['timestamp'].iloc[1]
# Out:
# 1546293541000000000

# %%
relevant_period['timestamp'].iloc[3]
# Out:
# 1546293536000000000

# %%
relevant_period.iloc[0]
# Out:
# sensor_id                      7277
# sensor_namee                 SDS011
# lat                          59.266
# lon                           15.23
# timestamp       1546293529000000000
# p1                            11.11
# p2                             3.52
# Name: 78090, dtype: object

# %%
relevant_period.iloc[1]
# Out:
# sensor_id                      7499
# sensor_namee                 SDS011
# lat                          59.924
# lon                          10.738
# timestamp       1546293541000000000
# p1                            17.81
# p2                             4.43
# Name: 78094, dtype: object

# %%
relevant_period.iloc[2]
# Out:
# sensor_id                      7597
# sensor_namee                 SDS011
# lat                           59.32
# lon                          18.064
# timestamp       1546293531000000000
# p1                            75.32
# p2                            39.88
# Name: 78095, dtype: object

# %%
relevant_period.shape
# Out:
# (48799, 7)

# %%
# turn the timestamp column into an epoch column 
relevant_period['timestamp'] = relevant_period['timestamp'].astype( 'int64' )

# %%
# extract data just for one sensor
relevant_period__single_sensor = relevant_period[ relevant_period['sensor_id'] == 7597  ]

# %%
relevant_period__single_sensor.shape
# Out:
# (280, 7)

# %%
starttime = time.time()
out = 0
out_time = 0
for index in range( relevant_period__single_sensor.shape[0] ) :
    out = relevant_period__single_sensor.iloc[ index ]['p1']
    out_time = relevant_period__single_sensor.iloc[ index ]['timestamp']
#     print( "index : "+str( index ) )
#     print( relevant_period.iloc[ index ] )
    # check if the the relevant measurment ( in the variable above ) is within the 
    # relevant time period.
    # - loop through the time range and see if the current timestamp is within that

print(' well, that took '+str( time.time() - starttime )+' seconds  ')
# Out:
#  well, that took 0.15907692909240723 seconds

# %%
# try convert the timestamp in the data, to epoch

in_data = pd.read_csv( "/Users/miska/Documents/open_something/luftdaten/luftdaten_code/luftdaten__make_tabular_data__from_db_data/ld_NYE_midnight_24hrs_nordics_all_data_01.cs
# 122297  1.72
# 122470  1.76
# 122647  1.96
# 122824  1.98
# 122998  1.62
# 123174  1.85
# 123351  2.00
# 123518  2.00
# 123703  1.95
# 123881  1.72
# 124063  1.64
# 124236  1.68
# 124356  1.66
# 124539  1.62
# 124776  1.59
# 125095  1.65
# 125198  1.50
# 125296  1.50
# 125400  1.54
# 125748  1.64
# 125830  1.55
# 126007  1.50
# 126182  1.40
# 126353  1.65
# 126535  1.56
# 126711  1.55
# 126979  1.50
# 127084  1.30
#
# [716 rows x 7 columns]

# %%
unique_vals_for_sensor_id_7273.iloc[2]
# Out:
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:04:31
# p1                              3.6
# p2                              1.6
# Name: 346, dtype: object

# %%
# %time
for row_i in range( unique_vals_for_sensor_id_7273.shape[0] ):
    print( unique_vals_for_sensor_id_7273.iloc[ row_i] )
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2018-12-31 11:57:22
# p1                             3.43
# p2                             1.56
# Name: 0, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2018-12-31 11:59:50
# p1                             3.78
# p2                             1.55
# Name: 175, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:04:31
# p1                              3.6
# p2                              1.6
# Name: 346, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:07:00
# p1                             2.47
# p2                             1.44
# Name: 522, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:09:28
# p1                             1.97
# p2                             1.38
# Name: 700, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:11:57
# p1                             1.87
# p2                             1.25
# Name: 873, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:16:54
# p1                              2.6
# p2                             1.59
# Name: 1047, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:19:25
# p1                             1.98
# p2                             1.48
# Name: 1225, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:21:53
# p1                             2.24
# p2                             1.28
# Name: 1404, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:24:22
# p1                             3.32
# p2                             1.52
# Name: 1581, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:26:50
# p1                             2.52
# p2                             1.38
# Name: 1758, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:31:47
# p1                             1.72
# p2                              1.2
# Name: 1938, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:34:16
# p1                             2.14
# p2                             1.05
# Name: 2110, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:36:47
# p1                             2.54
# p2                              1.1
# Name: 2288, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:39:16
# p1                             2.18
# p2                              1.2
# Name: 2463, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:41:44
# p1                             1.95
# p2                             1.15
# Name: 2642, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:46:41
# p1                             1.78
# p2                             1.03
# Name: 2817, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:49:10
# p1                             1.48
# p2                             0.94
# Name: 2992, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:54:07
# p1                             1.88
# p2                             1.05
# Name: 3187, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 12:56:35
# p1                             1.97
# p2                             1.15
# Name: 3347, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:01:35
# p1                             1.63
# p2                             0.95
# Name: 3525, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:04:07
# p1                             1.46
# p2                             0.97
# Name: 3707, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:06:35
# p1                             2.44
# p2                             1.15
# Name: 3884, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:09:04
# p1                             2.98
# p2                             1.18
# Name: 4063, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:11:33
# p1                             2.48
# p2                             1.05
# Name: 4241, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:16:40
# p1                             1.64
# p2                             0.98
# Name: 4419, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:19:09
# p1                             2.25
# p2                             0.95
# Name: 4597, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:21:44
# p1                             2.48
# p2                             0.99
# Name: 4774, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:24:31
# p1                             2.27
# p2                             0.95
# Name: 4953, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:27:00
# p1                             1.37
# p2                             0.82
# Name: 5131, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:32:00
# p1                              1.2
# p2                             0.84
# Name: 5310, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:34:33
# p1                             1.25
# p2                             0.82
# Name: 5486, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:37:02
# p1                             1.52
# p2                              0.9
# Name: 5661, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:39:38
# p1                             2.12
# p2                             1.05
# Name: 5840, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:42:14
# p1                             1.65
# p2                                1
# Name: 6020, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:44:43
# p1                             1.14
# p2                             0.85
# Name: 6194, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:49:46
# p1                             1.35
# p2                              0.8
# Name: 6371, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:52:15
# p1                             1.65
# p2                             0.75
# Name: 6544, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:54:44
# p1                             1.55
# p2                             0.84
# Name: 6719, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:57:12
# p1                             1.68
# p2                             0.94
# Name: 6896, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 13:59:41
# p1                             2.22
# p2                             0.92
# Name: 7078, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:04:41
# p1                             1.42
# p2                             1.03
# Name: 7252, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:07:10
# p1                             1.54
# p2                             0.95
# Name: 7426, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:09:38
# p1                             1.38
# p2                             0.78
# Name: 7607, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:12:07
# p1                             1.23
# p2                              0.8
# Name: 7783, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:14:36
# p1                             1.23
# p2                             0.85
# Name: 7962, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:19:35
# p1                             2.18
# p2                              0.8
# Name: 8137, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:22:05
# p1                             1.62
# p2                             0.75
# Name: 8314, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:24:34
# p1                             1.92
# p2                             0.84
# Name: 8492, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:27:02
# p1                             1.86
# p2                             0.85
# Name: 8673, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:31:59
# p1                             1.61
# p2                             0.84
# Name: 8842, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:34:30
# p1                             0.91
# p2                              0.7
# Name: 9019, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:36:59
# p1                             1.18
# p2                             0.65
# Name: 9196, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:39:28
# p1                             1.92
# p2                             0.75
# Name: 9379, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:41:58
# p1                             1.64
# p2                             0.75
# Name: 9549, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:46:55
# p1                                1
# p2                             0.71
# Name: 9729, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:49:24
# p1                              1.2
# p2                             0.82
# Name: 9905, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:51:53
# p1                              1.4
# p2                             0.85
# Name: 10083, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:54:21
# p1                             1.58
# p2                             0.75
# Name: 10263, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:56:52
# p1                             1.75
# p2                             0.78
# Name: 10438, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 14:59:21
# p1                             1.75
# p2                             0.88
# Name: 10613, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:04:32
# p1                              0.6
# p2                              0.6
# Name: 10791, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:07:01
# p1                             0.99
# p2                              0.6
# Name: 10967, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:09:29
# p1                             1.08
# p2                              0.6
# Name: 11143, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:12:01
# p1                              0.7
# p2                              0.6
# Name: 11326, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:14:34
# p1                             0.65
# p2                              0.6
# Name: 11501, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:19:31
# p1                             1.38
# p2                             0.66
# Name: 11679, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:21:59
# p1                             1.75
# p2                             0.72
# Name: 11858, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:24:29
# p1                             1.12
# p2                              0.7
# Name: 12037, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:26:57
# p1                             0.68
# p2                              0.6
# Name: 12217, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:31:54
# p1                             0.99
# p2                              0.6
# Name: 12395, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:34:23
# p1                             0.64
# p2                             0.55
# Name: 12571, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:36:53
# p1                             0.64
# p2                             0.55
# Name: 12750, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:39:24
# p1                             0.75
# p2                             0.55
# Name: 12925, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:41:53
# p1                             0.85
# p2                             0.55
# Name: 13106, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:46:50
# p1                             0.78
# p2                             0.56
# Name: 13285, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:46:50
# p1                             0.82
# p2                             0.58
# Name: 13462, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:51:49
# p1                              0.5
# p2                              0.5
# Name: 13638, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:54:20
# p1                             0.55
# p2                             0.55
# Name: 13815, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 15:56:49
# p1                              0.5
# p2                              0.5
# Name: 13993, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:01:46
# p1                             1.14
# p2                              0.5
# Name: 14161, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:04:15
# p1                             0.84
# p2                              0.6
# Name: 14333, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:06:45
# p1                             0.84
# p2                              0.6
# Name: 14510, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:09:13
# p1                             0.68
# p2                             0.56
# Name: 14683, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:11:42
# p1                              1.8
# p2                             0.63
# Name: 14858, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:16:42
# p1                              1.1
# p2                              0.5
# Name: 15034, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:19:11
# p1                             1.05
# p2                             0.45
# Name: 15210, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:21:39
# p1                              0.5
# p2                              0.5
# Name: 15388, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:24:08
# p1                              1.1
# p2                             0.66
# Name: 15582, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:26:36
# p1                             1.42
# p2                             0.66
# Name: 15737, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:31:36
# p1                             0.56
# p2                             0.55
# Name: 15911, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:34:04
# p1                             0.73
# p2                             0.55
# Name: 16085, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:36:33
# p1                             0.62
# p2                             0.45
# Name: 16260, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:39:06
# p1                             0.58
# p2                             0.45
# Name: 16436, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:41:35
# p1                             0.58
# p2                             0.45
# Name: 16608, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:46:32
# p1                             1.62
# p2                             0.62
# Name: 16780, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:49:00
# p1                             1.25
# p2                             0.58
# Name: 16952, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:51:29
# p1                              1.2
# p2                             0.52
# Name: 17126, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:53:57
# p1                             1.38
# p2                             0.62
# Name: 17298, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 16:58:54
# p1                             0.61
# p2                             0.54
# Name: 17470, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:01:23
# p1                             0.48
# p2                             0.46
# Name: 17642, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:03:51
# p1                             0.62
# p2                             0.55
# Name: 17818, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:06:20
# p1                             0.82
# p2                             0.55
# Name: 17994, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:08:48
# p1                             0.85
# p2                              0.5
# Name: 18172, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:13:45
# p1                             0.74
# p2                             0.62
# Name: 18354, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:16:14
# p1                              0.6
# p2                              0.6
# Name: 18531, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:18:42
# p1                              0.7
# p2                              0.6
# Name: 18706, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:21:11
# p1                              1.7
# p2                              0.8
# Name: 18887, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:23:53
# p1                             1.75
# p2                             0.85
# Name: 19065, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:28:58
# p1                             1.07
# p2                             0.63
# Name: 19241, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:31:26
# p1                             1.22
# p2                             0.62
# Name: 19418, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:31:26
# p1                             1.47
# p2                             0.63
# Name: 19597, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:36:50
# p1                             0.53
# p2                             0.53
# Name: 19772, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:39:18
# p1                             0.86
# p2                             0.58
# Name: 19952, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:41:49
# p1                             1.72
# p2                             0.66
# Name: 20130, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:46:48
# p1                                2
# p2                             0.82
# Name: 20306, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:49:22
# p1                             1.68
# p2                              0.7
# Name: 20484, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:51:51
# p1                             1.96
# p2                             0.74
# Name: 20665, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:54:20
# p1                             1.56
# p2                             0.74
# Name: 20844, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 17:56:48
# p1                             1.08
# p2                              0.7
# Name: 21022, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:01:53
# p1                             3.15
# p2                             0.65
# Name: 21202, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:04:40
# p1                              1.1
# p2                             0.56
# Name: 21379, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:07:09
# p1                             1.85
# p2                             0.58
# Name: 21554, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:09:37
# p1                              2.5
# p2                             0.65
# Name: 21735, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:12:16
# p1                             1.88
# p2                             0.74
# Name: 21906, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:14:45
# p1                             1.38
# p2                             0.65
# Name: 22085, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:19:51
# p1                              3.2
# p2                             0.78
# Name: 22267, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:22:19
# p1                             2.15
# p2                             0.74
# Name: 22443, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:24:48
# p1                              1.5
# p2                             0.68
# Name: 22626, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:27:16
# p1                             1.28
# p2                             0.65
# Name: 22831, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:29:45
# p1                              2.9
# p2                             0.78
# Name: 22985, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:34:46
# p1                             1.58
# p2                             0.64
# Name: 23167, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:37:17
# p1                             2.13
# p2                             0.72
# Name: 23345, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:39:46
# p1                             2.46
# p2                             0.85
# Name: 23531, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:42:22
# p1                             2.76
# p2                             0.94
# Name: 23700, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:44:50
# p1                             3.06
# p2                             0.94
# Name: 23878, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:50:00
# p1                             3.18
# p2                             0.76
# Name: 24055, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:52:30
# p1                             1.74
# p2                             0.75
# Name: 24238, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:55:03
# p1                             1.42
# p2                             0.76
# Name: 24409, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 18:57:31
# p1                              1.8
# p2                             0.76
# Name: 24586, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:00:03
# p1                              2.2
# p2                             0.72
# Name: 24767, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:02:37
# p1                             1.98
# p2                             0.66
# Name: 24946, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:07:43
# p1                             3.07
# p2                              0.8
# Name: 25127, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:10:14
# p1                             2.18
# p2                             0.66
# Name: 25309, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:12:43
# p1                             2.13
# p2                             0.73
# Name: 25486, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:15:11
# p1                             1.68
# p2                             0.82
# Name: 25666, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:17:42
# p1                             1.58
# p2                              0.8
# Name: 25844, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:22:42
# p1                             1.78
# p2                             0.65
# Name: 26022, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:25:11
# p1                             1.62
# p2                             0.66
# Name: 26203, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:27:42
# p1                             1.75
# p2                             0.72
# Name: 26382, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:30:14
# p1                             0.94
# p2                              0.6
# Name: 26561, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:32:43
# p1                              0.7
# p2                             0.52
# Name: 26739, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:37:40
# p1                             1.42
# p2                             0.82
# Name: 26999, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:42:43
# p1                             1.38
# p2                             0.65
# Name: 27180, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:45:13
# p1                              1.5
# p2                             0.85
# Name: 27269, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:40:13
# p1                             1.44
# p2                             0.65
# Name: 27277, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:52:50
# p1                             2.06
# p2                              0.9
# Name: 27647, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:55:24
# p1                             1.96
# p2                              0.8
# Name: 27736, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:47:50
# p1                             1.55
# p2                              0.9
# Name: 27994, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 19:57:53
# p1                             1.16
# p2                             0.65
# Name: 28262, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:00:24
# p1                             0.85
# p2                             0.65
# Name: 28354, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:02:54
# p1                              1.3
# p2                             0.65
# Name: 28446, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:10:46
# p1                             1.54
# p2                             0.65
# Name: 28633, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:15:44
# p1                             1.15
# p2                             0.45
# Name: 28828, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:28:26
# p1                             2.26
# p2                             0.76
# Name: 29220, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:30:55
# p1                             1.08
# p2                             0.65
# Name: 29310, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:33:29
# p1                             1.02
# p2                             0.55
# Name: 29413, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:33:29
# p1                             1.47
# p2                              0.6
# Name: 29590, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:07:58
# p1                             1.66
# p2                             0.67
# Name: 30296, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:13:14
# p1                             1.38
# p2                              0.5
# Name: 30470, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:18:23
# p1                             1.75
# p2                             0.52
# Name: 30601, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 20:20:56
# p1                             1.95
# p2                             0.62
# Name: 30691, dtype: object
# ...
# Name: 117025, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:18:25
# p1                             3.53
# p2                             1.74
# Name: 117376, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:20:54
# p1                             3.56
# p2                              1.7
# Name: 117470, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:13:28
# p1                             4.07
# p2                             1.75
# Name: 117535, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:15:57
# p1                              3.2
# p2                             1.68
# Name: 117593, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:25:56
# p1                             3.67
# p2                              1.9
# Name: 117970, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:30:53
# p1                              3.1
# p2                             1.58
# Name: 118200, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:28:24
# p1                             3.04
# p2                              1.8
# Name: 118298, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:33:21
# p1                             4.13
# p2                             1.58
# Name: 118439, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:35:50
# p1                             3.66
# p2                             1.64
# Name: 118616, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:40:49
# p1                             4.06
# p2                             2.04
# Name: 118809, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:43:18
# p1                             4.14
# p2                                2
# Name: 118972, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:45:46
# p1                             3.84
# p2                             1.86
# Name: 119153, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:48:15
# p1                              4.3
# p2                             1.92
# Name: 119333, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:50:43
# p1                             4.88
# p2                              2.1
# Name: 119504, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:55:40
# p1                             5.62
# p2                             2.18
# Name: 119673, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 09:58:09
# p1                             6.62
# p2                             2.25
# Name: 119855, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:00:37
# p1                             5.66
# p2                             2.44
# Name: 120023, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:03:06
# p1                             5.92
# p2                             2.26
# Name: 120196, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:05:34
# p1                             6.26
# p2                             2.06
# Name: 120372, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:10:31
# p1                             4.65
# p2                             2.15
# Name: 120545, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:12:59
# p1                             4.52
# p2                                2
# Name: 120718, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:15:28
# p1                              4.4
# p2                              2.1
# Name: 120893, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:17:56
# p1                              4.2
# p2                                2
# Name: 121070, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:22:53
# p1                             3.57
# p2                             1.74
# Name: 121241, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:25:22
# p1                             3.06
# p2                              1.9
# Name: 121410, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:27:50
# p1                             3.88
# p2                              1.9
# Name: 121593, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:30:19
# p1                             3.87
# p2                             1.95
# Name: 121769, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:32:47
# p1                             3.85
# p2                             1.86
# Name: 121946, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:37:44
# p1                             3.83
# p2                             1.76
# Name: 122128, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:40:16
# p1                             3.63
# p2                             1.72
# Name: 122297, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:42:44
# p1                             3.43
# p2                             1.76
# Name: 122470, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:45:13
# p1                             3.32
# p2                             1.96
# Name: 122647, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:47:44
# p1                                4
# p2                             1.98
# Name: 122824, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:52:44
# p1                             2.97
# p2                             1.62
# Name: 122998, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:55:12
# p1                             3.32
# p2                             1.85
# Name: 123174, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 10:57:41
# p1                             4.37
# p2                                2
# Name: 123351, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:00:09
# p1                             4.05
# p2                                2
# Name: 123518, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:02:38
# p1                              4.3
# p2                             1.95
# Name: 123703, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:07:35
# p1                              3.5
# p2                             1.72
# Name: 123881, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:10:03
# p1                             2.42
# p2                             1.64
# Name: 124063, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:12:32
# p1                              2.6
# p2                             1.68
# Name: 124236, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:15:00
# p1                              4.6
# p2                             1.66
# Name: 124356, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:22:26
# p1                              3.6
# p2                             1.62
# Name: 124539, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:19:57
# p1                             4.16
# p2                             1.59
# Name: 124776, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:24:54
# p1                             3.46
# p2                             1.65
# Name: 125095, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:27:23
# p1                             2.76
# p2                              1.5
# Name: 125198, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:29:51
# p1                             2.88
# p2                              1.5
# Name: 125296, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:34:49
# p1                             2.76
# p2                             1.54
# Name: 125400, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:37:17
# p1                             2.33
# p2                             1.64
# Name: 125748, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:39:45
# p1                             2.35
# p2                             1.55
# Name: 125830, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:42:15
# p1                             3.08
# p2                              1.5
# Name: 126007, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:44:44
# p1                             3.62
# p2                              1.4
# Name: 126182, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:49:40
# p1                             3.46
# p2                             1.65
# Name: 126353, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:52:09
# p1                             3.01
# p2                             1.56
# Name: 126535, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:54:37
# p1                             2.54
# p2                             1.55
# Name: 126711, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:57:06
# p1                              3.2
# p2                              1.5
# Name: 126979, dtype: object
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2019-01-01 11:59:34
# p1                             2.63
# p2                              1.3
# Name: 127084, dtype: object

# %%
# !uptime
# Out:
# 16:54  up  1:51, 4 users, load averages: 1.42 1.49 1.57
