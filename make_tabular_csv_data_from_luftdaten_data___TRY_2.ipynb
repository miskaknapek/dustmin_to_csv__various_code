# %%
import pandas as pd
import numpy as np
import time

# %%
# parameters

# start_time = "2018-12-31 21:58:42"
end_time = "2019-01-01 11:58:42"
# generate this please
start_time = "?????"

time_frequency_for_periods__for_basic_data = "5T"
num_of_time_periods___for_basic_data = 24*20 # 24 hrs * 12 x 5 mins in each hour

# when generating time periods 
sampling_frequency = "3T"



# --- data urls 

curr_url = "????"
nordic_midnight_24_hrs_data__url = "/Users/miska/Documents/open_something/luftdaten/luftdaten_code/luftdaten__make_tabular_data__from_db_data/ld_NYE_midnight_24hrs_nordics_all_data_01.csv"

# set the current data source 
curr_url =nordic_midnight_24_hrs_data__url

# %%
# try convert the timestamp in the data, to epoch

in_data = pd.read_csv( curr_url )
in_data.shape
# Out:
# (127109, 7)

# %%
in_data.dtypes
# Out:
# sensor_id         int64
# sensor_namee     object
# lat             float64
# lon             float64
# timestamp        object
# p1              float64
# p2              float64
# dtype: object

# %%
in_data['timestamp'] = pd.to_datetime( in_data['timestamp'] )

# %%
in_data.head()
# Out:
#    sensor_id sensor_namee     lat     lon           timestamp      p1     p2
# 0       7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43   1.56
# 1       7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77  33.82
# 2       7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48   2.47
# 3       7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05   6.62
# 4       7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78   1.02

# %%
in_data.tail()
# Out:
#         sensor_id sensor_namee     lat     lon           timestamp     p1  \
# 127104      16723       SDS011  57.736  11.894 2019-01-01 11:58:57  16.47
# 127105      16815       SDS011  59.462  18.040 2019-01-01 11:59:36   2.67
# 127106      17235       SDS011  59.272  17.780 2019-01-01 11:59:41   4.69
# 127107      10588       SDS011  55.676  13.346 2019-01-01 11:57:12  14.08
# 127108      10647       SDS011  55.608  13.036 2019-01-01 11:58:42  23.42
#
#           p2
# 127104  3.40
# 127105  1.97
# 127106  1.82
# 127107  3.68
# 127108  4.75

# %%
in_data2 = in_data.copy()

# %%
in_data2['timestamp'] = in_data['timestamp'].astype( 'int64' )

# %%
in_data2.head()
# Out:
#    sensor_id sensor_namee     lat     lon            timestamp      p1     p2
# 0       7273       SDS011  60.002  17.846  1546257442000000000    3.43   1.56
# 1       7275       SDS011  57.720  11.888  1546257524000000000  482.77  33.82
# 2       7277       SDS011  59.266  15.230  1546257527000000000    5.48   2.47
# 3       7406       SDS011  56.964  24.128  1546257401000000000   11.05   6.62
# 4       7428       SDS011  59.868  17.624  1546257462000000000    1.78   1.02

# %%
in_data2.tail()
# Out:
#         sensor_id sensor_namee     lat     lon            timestamp     p1  \
# 127104      16723       SDS011  57.736  11.894  1546343937000000000  16.47
# 127105      16815       SDS011  59.462  18.040  1546343976000000000   2.67
# 127106      17235       SDS011  59.272  17.780  1546343981000000000   4.69
# 127107      10588       SDS011  55.676  13.346  1546343832000000000  14.08
# 127108      10647       SDS011  55.608  13.036  1546343922000000000  23.42
#
#           p2
# 127104  3.40
# 127105  1.97
# 127106  1.82
# 127107  3.68
# 127108  4.75

# %%
### various time operations

# %%
end_time
# Out:
# '2019-01-01 11:58:42'

# %%
# generate the time slots when the data is sampled

data_sampling_windows__time_periods = pd.date_range( end_time, freq=sampling_frequency,  
periods=num_of_time_periods___for_basic_data+1)

# %%
# check generated times
data_sampling_windows__time_periods
# Out:
# DatetimeIndex(['2019-01-01 11:58:42', '2019-01-01 12:01:42',
#                '2019-01-01 12:04:42', '2019-01-01 12:07:42',
#                '2019-01-01 12:10:42', '2019-01-01 12:13:42',
#                '2019-01-01 12:16:42', '2019-01-01 12:19:42',
#                '2019-01-01 12:22:42', '2019-01-01 12:25:42',
#                ...
#                '2019-01-02 11:31:42', '2019-01-02 11:34:42',
#                '2019-01-02 11:37:42', '2019-01-02 11:40:42',
#                '2019-01-02 11:43:42', '2019-01-02 11:46:42',
#                '2019-01-02 11:49:42', '2019-01-02 11:52:42',
#                '2019-01-02 11:55:42', '2019-01-02 11:58:42'],
#               dtype='datetime64[ns]', length=481, freq='3T')

# %%
# then to 'go back in time' from the end date

# adding the '+1' to avoid the off by one errors  
data_sampling_windows__time_periods = data_sampling_windows__time_periods - ( num_of_time_periods___for_basic_data
 + 1 )

# %%
data_sampling_windows__time_periods[0]
# Out:
# Timestamp('2018-12-31 11:55:42', freq='3T')

# %%
data_sampling_windows__time_periods
# Out:
# DatetimeIndex(['2018-12-31 11:55:42', '2018-12-31 11:58:42',
#                '2018-12-31 12:01:42', '2018-12-31 12:04:42',
#                '2018-12-31 12:07:42', '2018-12-31 12:10:42',
#                '2018-12-31 12:13:42', '2018-12-31 12:16:42',
#                '2018-12-31 12:19:42', '2018-12-31 12:22:42',
#                ...
#                '2019-01-01 11:28:42', '2019-01-01 11:31:42',
#                '2019-01-01 11:34:42', '2019-01-01 11:37:42',
#                '2019-01-01 11:40:42', '2019-01-01 11:43:42',
#                '2019-01-01 11:46:42', '2019-01-01 11:49:42',
#                '2019-01-01 11:52:42', '2019-01-01 11:55:42'],
#               dtype='datetime64[ns]', length=481, freq='3T')

# %%
data_sampling_windows__time_periods.shape
# Out:
# (481,)

# %%
end_time = pd.to_datetime( end_time )
end_time
# Out:
# Timestamp('2019-01-01 11:58:42')

# %%
start_time = data_sampling_windows__time_periods[0]
start_time
# Out:
# Timestamp('2018-12-31 11:55:42', freq='3T')

# %%
### Fetch relevant time period, of data from csv 

relev_time_period = in_data[ in_data['timestamp'] >= start_time ]
relev_time_period = relev_time_period[ relev_time_period['timestamp'] < end_time ]


in_data.shape, relev_time_period.shape
# Out:
# ((127109, 7), (84702, 7))

# %%
relev_time_period.head()
# Out:
#    sensor_id sensor_namee     lat     lon           timestamp      p1     p2
# 0       7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43   1.56
# 1       7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77  33.82
# 2       7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48   2.47
# 3       7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05   6.62
# 4       7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78   1.02

# %%
relev_time_period.tail()
# Out:
#         sensor_id sensor_namee     lat     lon           timestamp     p1  \
# 127083      19301       SDS011  59.362  12.152 2019-01-01 11:56:50   0.02
# 127097      12990       SDS011  57.692  11.958 2019-01-01 11:58:00  16.63
# 127101      16153       SDS011  55.648  13.208 2019-01-01 11:57:19  20.00
# 127103      16533       SDS011  55.722  13.202 2019-01-01 11:56:55  18.05
# 127107      10588       SDS011  55.676  13.346 2019-01-01 11:57:12  14.08
#
#           p2
# 127083  0.00
# 127097  3.60
# 127101  3.90
# 127103  4.33
# 127107  3.68

# %%
# --- now loop through the different sensor datas

# %%
unique_sensor_ids = relev_time_period['sensor_id'].unique()
unique_sensor_ids.shape
# Out:
# (200,)

# %%
# temporary storage location for out arrays 
out_array_w_generated_periodic_data_arrays = []

# prepare the out array, beforhand
## curr_sensor_measurements_for_all_time_periods = np.zeros( data_sampling_windows__time_periods.shape[0] )

curr_sensor_id_i = 0

starttime = time.time() 

# Loop through the different sensor ( numbers )
for sensor_id_ in unique_sensor_ids[:10]:
    print("-- working on sensor id "+str( sensor_id_ )+" |  "+str( curr_sensor_id_i )+"/"+str( unique_sensor_ids.shape[0] )  )
    curr_sensor_id_i = curr_sensor_id_i + 1
    
    # fetch the measurements for this sensor id
    curr_sensor_id_measurements = relev_time_period[ relev_time_period['sensor_id'] == sensor_id_  ]
    
    # sort them by time 
    curr_sensor_id_measurements = curr_sensor_id_measurements.sort_values( by=['timestamp'] ) 
    ## print("--- current sensor id has "+str( curr_sensor_id_measurements.shape[0])+" measurements" )
    
    curr_sensor_id_measurements__only_timestamps = curr_sensor_id_measurements['timestamp']
    curr_sensor_id_measurements__only_p1_vals = curr_sensor_id_measurements['p1']
    curr_sensor_id_measurements__only_p2_vals = curr_sensor_id_measurements['p2']
    
    # -- make sure all the measurements of the given time period are there
    
    # make an array with enough slots for all time periods
    curr_sensor_measurements_for_all_time_periods = np.zeros( data_sampling_windows__time_periods.shape[0] )
    ## print(" --- curr_sensor_measurements_for_all_time_periods.shape = "+str( curr_sensor_measurements_for_all_time_periods.shape ))
    ## print( curr_sensor_measurements_for_all_time_periods )
    
    # loop through all values in the data 
    for curr_sensor_measurements_row_i in range( curr_sensor_id_measurements__only_timestamps.shape[0] ):
    ### for curr_sensor_measurements_row_i in range( 10 ):
        ## print("\n-- -- working on measurement #"+str( curr_sensor_measurements_row_i )+" (pm2.5/10  : "+str(curr_sensor_id_measurements__only_p1_vals.iloc[ curr_sensor_measurements_row_i])+"/"+str(curr_sensor_id_measurements__only_p2_vals.iloc[ curr_sensor_measurements_row_i])+") - with timestamp "+str( curr_sensor_id_measurements__only_timestamps.iloc[ curr_sensor_measurements_row_i ] ) )
        
        # loop through the available timestamps, and see whether the current time stamp
        # is within these. 
        # - if it is, then insert it at the appropiate current index 
        # in the out array
        
        # optimisation variable to remember where the last 
        # value was found, in time
        # - the idea is that we start the next search in time indicies, 
        #   only after the last found position, so we can skip checking the previous positions 
        last_found_time_index = 0 
        # note the optimisation above and below 
        for all_relev_timestamps_array__current_index in range( last_found_time_index, data_sampling_windows__time_periods.shape[0]-1 ):
        ### unoptimised edition : 
        ### for all_relev_timestamps_array__current_index in range( data_sampling_windows__time_periods.shape[0]-1 ):
        ### for all_relev_timestamps_array__current_index in range( 100 ):
        
            # print("-- -- -- looping through available timestamps - loooking at index #"+str( all_relev_timestamps_array__current_index )+" : timestamp "+str( data_sampling_windows__time_periods[ all_relev_timestamps_array__current_index ] ))
            #
            if curr_sensor_id_measurements__only_timestamps.iloc[ curr_sensor_measurements_row_i ] > data_sampling_windows__time_periods[ all_relev_timestamps_array__current_index ] and curr_sensor_id_measurements__only_timestamps.iloc[ curr_sensor_measurements_row_i ] < data_sampling_windows__time_periods[ all_relev_timestamps_array__current_index+1 ]:
                
                print(" -- -- -- -- YAY! the current timestamp ( "+str(  curr_sensor_id_measurements__only_timestamps.iloc[ curr_sensor_measurements_row_i ]  )+" is within the specified time ranges, at index "+str( all_relev_timestamps_array__current_index )+" amongst the possible time periods data. ie. btw "+str( data_sampling_windows__time_periods[ all_relev_timestamps_array__current_index ])+" and "+str( data_sampling_windows__time_periods[ all_relev_timestamps_array__current_index ]+1 ) )
                # 
                # assign the current PM value as appropriate 
                curr_sensor_measurements_for_all_time_periods[ all_relev_timestamps_array__current_index ] = curr_sensor_id_measurements__only_p1_vals.iloc[ curr_sensor_measurements_row_i ]
                
                # set the variable suggesting which position 
                # the timestamp was found in, 
                # and which position the next search should start from 
                last_found_time_index = all_relev_timestamps_array__current_index
                
                #
                # no need to continue finding possible time slots - just break
                break
                
    # END OF DIFFERENT SENSOR LOOPING
    # print the resulting values slotted array - ie array with slots 
    # for values, formatted according to time slots
    ## print( " <<< resulting periodic values array : ")
    ## print( curr_sensor_measurements_for_all_time_periods )
    out_array_w_generated_periodic_data_arrays.append( curr_sensor_measurements_for_all_time_periods )
                
# ende
print( "- done after "+str( time.time() - starttime )+" seconds " )
# Out:
# -- working on sensor id 7273 |  0/200
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 11:57:22 is within the specified time ranges, at index 0 amongst the possible time periods data. ie. btw 2018-12-31 11:55:42 and 2018-12-31 11:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 11:59:50 is within the specified time ranges, at index 1 amongst the possible time periods data. ie. btw 2018-12-31 11:58:42 and 2018-12-31 12:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:04:47 is within the specified time ranges, at index 3 amongst the possible time periods data. ie. btw 2018-12-31 12:04:42 and 2018-12-31 12:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:07:16 is within the specified time ranges, at index 3 amongst the possible time periods data. ie. btw 2018-12-31 12:04:42 and 2018-12-31 12:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:09:44 is within the specified time ranges, at index 4 amongst the possible time periods data. ie. btw 2018-12-31 12:07:42 and 2018-12-31 12:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:12:13 is within the specified time ranges, at index 5 amongst the possible time periods data. ie. btw 2018-12-31 12:10:42 and 2018-12-31 12:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:14:43 is within the specified time ranges, at index 6 amongst the possible time periods data. ie. btw 2018-12-31 12:13:42 and 2018-12-31 12:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:19:43 is within the specified time ranges, at index 8 amongst the possible time periods data. ie. btw 2018-12-31 12:19:42 and 2018-12-31 12:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:22:12 is within the specified time ranges, at index 8 amongst the possible time periods data. ie. btw 2018-12-31 12:19:42 and 2018-12-31 12:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:24:40 is within the specified time ranges, at index 9 amongst the possible time periods data. ie. btw 2018-12-31 12:22:42 and 2018-12-31 12:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:27:09 is within the specified time ranges, at index 10 amongst the possible time periods data. ie. btw 2018-12-31 12:25:42 and 2018-12-31 12:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:27:09 is within the specified time ranges, at index 10 amongst the possible time periods data. ie. btw 2018-12-31 12:25:42 and 2018-12-31 12:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:29:37 is within the specified time ranges, at index 11 amongst the possible time periods data. ie. btw 2018-12-31 12:28:42 and 2018-12-31 12:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:29:37 is within the specified time ranges, at index 11 amongst the possible time periods data. ie. btw 2018-12-31 12:28:42 and 2018-12-31 12:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:34:35 is within the specified time ranges, at index 12 amongst the possible time periods data. ie. btw 2018-12-31 12:31:42 and 2018-12-31 12:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:37:03 is within the specified time ranges, at index 13 amongst the possible time periods data. ie. btw 2018-12-31 12:34:42 and 2018-12-31 12:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:39:32 is within the specified time ranges, at index 14 amongst the possible time periods data. ie. btw 2018-12-31 12:37:42 and 2018-12-31 12:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:42:00 is within the specified time ranges, at index 15 amongst the possible time periods data. ie. btw 2018-12-31 12:40:42 and 2018-12-31 12:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:46:57 is within the specified time ranges, at index 17 amongst the possible time periods data. ie. btw 2018-12-31 12:46:42 and 2018-12-31 12:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:49:26 is within the specified time ranges, at index 17 amongst the possible time periods data. ie. btw 2018-12-31 12:46:42 and 2018-12-31 12:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:51:54 is within the specified time ranges, at index 18 amongst the possible time periods data. ie. btw 2018-12-31 12:49:42 and 2018-12-31 12:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:54:23 is within the specified time ranges, at index 19 amongst the possible time periods data. ie. btw 2018-12-31 12:52:42 and 2018-12-31 12:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 12:56:51 is within the specified time ranges, at index 20 amongst the possible time periods data. ie. btw 2018-12-31 12:55:42 and 2018-12-31 12:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:01:48 is within the specified time ranges, at index 22 amongst the possible time periods data. ie. btw 2018-12-31 13:01:42 and 2018-12-31 13:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:04:17 is within the specified time ranges, at index 22 amongst the possible time periods data. ie. btw 2018-12-31 13:01:42 and 2018-12-31 13:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:06:45 is within the specified time ranges, at index 23 amongst the possible time periods data. ie. btw 2018-12-31 13:04:42 and 2018-12-31 13:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:09:14 is within the specified time ranges, at index 24 amongst the possible time periods data. ie. btw 2018-12-31 13:07:42 and 2018-12-31 13:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:11:42 is within the specified time ranges, at index 25 amongst the possible time periods data. ie. btw 2018-12-31 13:10:42 and 2018-12-31 13:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:16:47 is within the specified time ranges, at index 27 amongst the possible time periods data. ie. btw 2018-12-31 13:16:42 and 2018-12-31 13:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:19:17 is within the specified time ranges, at index 27 amongst the possible time periods data. ie. btw 2018-12-31 13:16:42 and 2018-12-31 13:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:21:48 is within the specified time ranges, at index 28 amongst the possible time periods data. ie. btw 2018-12-31 13:19:42 and 2018-12-31 13:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:24:17 is within the specified time ranges, at index 29 amongst the possible time periods data. ie. btw 2018-12-31 13:22:42 and 2018-12-31 13:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:26:48 is within the specified time ranges, at index 30 amongst the possible time periods data. ie. btw 2018-12-31 13:25:42 and 2018-12-31 13:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:31:53 is within the specified time ranges, at index 32 amongst the possible time periods data. ie. btw 2018-12-31 13:31:42 and 2018-12-31 13:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:34:24 is within the specified time ranges, at index 32 amongst the possible time periods data. ie. btw 2018-12-31 13:31:42 and 2018-12-31 13:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:36:52 is within the specified time ranges, at index 33 amongst the possible time periods data. ie. btw 2018-12-31 13:34:42 and 2018-12-31 13:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:39:21 is within the specified time ranges, at index 34 amongst the possible time periods data. ie. btw 2018-12-31 13:37:42 and 2018-12-31 13:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:41:49 is within the specified time ranges, at index 35 amongst the possible time periods data. ie. btw 2018-12-31 13:40:42 and 2018-12-31 13:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:46:46 is within the specified time ranges, at index 37 amongst the possible time periods data. ie. btw 2018-12-31 13:46:42 and 2018-12-31 13:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:49:15 is within the specified time ranges, at index 37 amongst the possible time periods data. ie. btw 2018-12-31 13:46:42 and 2018-12-31 13:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:51:43 is within the specified time ranges, at index 38 amongst the possible time periods data. ie. btw 2018-12-31 13:49:42 and 2018-12-31 13:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:54:14 is within the specified time ranges, at index 39 amongst the possible time periods data. ie. btw 2018-12-31 13:52:42 and 2018-12-31 13:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 13:56:42 is within the specified time ranges, at index 40 amongst the possible time periods data. ie. btw 2018-12-31 13:55:42 and 2018-12-31 13:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:01:39 is within the specified time ranges, at index 41 amongst the possible time periods data. ie. btw 2018-12-31 13:58:42 and 2018-12-31 14:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:04:08 is within the specified time ranges, at index 42 amongst the possible time periods data. ie. btw 2018-12-31 14:01:42 and 2018-12-31 14:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:06:36 is within the specified time ranges, at index 43 amongst the possible time periods data. ie. btw 2018-12-31 14:04:42 and 2018-12-31 14:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:09:05 is within the specified time ranges, at index 44 amongst the possible time periods data. ie. btw 2018-12-31 14:07:42 and 2018-12-31 14:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:11:34 is within the specified time ranges, at index 45 amongst the possible time periods data. ie. btw 2018-12-31 14:10:42 and 2018-12-31 14:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:16:30 is within the specified time ranges, at index 46 amongst the possible time periods data. ie. btw 2018-12-31 14:13:42 and 2018-12-31 14:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:18:59 is within the specified time ranges, at index 47 amongst the possible time periods data. ie. btw 2018-12-31 14:16:42 and 2018-12-31 14:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:21:28 is within the specified time ranges, at index 48 amongst the possible time periods data. ie. btw 2018-12-31 14:19:42 and 2018-12-31 14:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:23:57 is within the specified time ranges, at index 49 amongst the possible time periods data. ie. btw 2018-12-31 14:22:42 and 2018-12-31 14:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:28:54 is within the specified time ranges, at index 51 amongst the possible time periods data. ie. btw 2018-12-31 14:28:42 and 2018-12-31 14:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:31:23 is within the specified time ranges, at index 51 amongst the possible time periods data. ie. btw 2018-12-31 14:28:42 and 2018-12-31 14:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:33:51 is within the specified time ranges, at index 52 amongst the possible time periods data. ie. btw 2018-12-31 14:31:42 and 2018-12-31 14:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:36:20 is within the specified time ranges, at index 53 amongst the possible time periods data. ie. btw 2018-12-31 14:34:42 and 2018-12-31 14:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:38:50 is within the specified time ranges, at index 54 amongst the possible time periods data. ie. btw 2018-12-31 14:37:42 and 2018-12-31 14:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:43:47 is within the specified time ranges, at index 56 amongst the possible time periods data. ie. btw 2018-12-31 14:43:42 and 2018-12-31 14:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:46:16 is within the specified time ranges, at index 56 amongst the possible time periods data. ie. btw 2018-12-31 14:43:42 and 2018-12-31 14:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:48:47 is within the specified time ranges, at index 57 amongst the possible time periods data. ie. btw 2018-12-31 14:46:42 and 2018-12-31 14:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:51:16 is within the specified time ranges, at index 58 amongst the possible time periods data. ie. btw 2018-12-31 14:49:42 and 2018-12-31 14:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 14:53:45 is within the specified time ranges, at index 59 amongst the possible time periods data. ie. btw 2018-12-31 14:52:42 and 2018-12-31 14:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:01:10 is within the specified time ranges, at index 61 amongst the possible time periods data. ie. btw 2018-12-31 14:58:42 and 2018-12-31 15:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:03:39 is within the specified time ranges, at index 62 amongst the possible time periods data. ie. btw 2018-12-31 15:01:42 and 2018-12-31 15:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:06:07 is within the specified time ranges, at index 63 amongst the possible time periods data. ie. btw 2018-12-31 15:04:42 and 2018-12-31 15:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:08:36 is within the specified time ranges, at index 64 amongst the possible time periods data. ie. btw 2018-12-31 15:07:42 and 2018-12-31 15:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:13:33 is within the specified time ranges, at index 65 amongst the possible time periods data. ie. btw 2018-12-31 15:10:42 and 2018-12-31 15:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:16:01 is within the specified time ranges, at index 66 amongst the possible time periods data. ie. btw 2018-12-31 15:13:42 and 2018-12-31 15:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:18:30 is within the specified time ranges, at index 67 amongst the possible time periods data. ie. btw 2018-12-31 15:16:42 and 2018-12-31 15:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:20:58 is within the specified time ranges, at index 68 amongst the possible time periods data. ie. btw 2018-12-31 15:19:42 and 2018-12-31 15:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:25:55 is within the specified time ranges, at index 70 amongst the possible time periods data. ie. btw 2018-12-31 15:25:42 and 2018-12-31 15:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:28:24 is within the specified time ranges, at index 70 amongst the possible time periods data. ie. btw 2018-12-31 15:25:42 and 2018-12-31 15:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:30:52 is within the specified time ranges, at index 71 amongst the possible time periods data. ie. btw 2018-12-31 15:28:42 and 2018-12-31 15:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:33:21 is within the specified time ranges, at index 72 amongst the possible time periods data. ie. btw 2018-12-31 15:31:42 and 2018-12-31 15:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:35:49 is within the specified time ranges, at index 73 amongst the possible time periods data. ie. btw 2018-12-31 15:34:42 and 2018-12-31 15:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:40:48 is within the specified time ranges, at index 75 amongst the possible time periods data. ie. btw 2018-12-31 15:40:42 and 2018-12-31 15:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:43:16 is within the specified time ranges, at index 75 amongst the possible time periods data. ie. btw 2018-12-31 15:40:42 and 2018-12-31 15:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:45:45 is within the specified time ranges, at index 76 amongst the possible time periods data. ie. btw 2018-12-31 15:43:42 and 2018-12-31 15:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:48:13 is within the specified time ranges, at index 77 amongst the possible time periods data. ie. btw 2018-12-31 15:46:42 and 2018-12-31 15:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:50:42 is within the specified time ranges, at index 78 amongst the possible time periods data. ie. btw 2018-12-31 15:49:42 and 2018-12-31 15:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:55:39 is within the specified time ranges, at index 79 amongst the possible time periods data. ie. btw 2018-12-31 15:52:42 and 2018-12-31 15:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 15:58:07 is within the specified time ranges, at index 80 amongst the possible time periods data. ie. btw 2018-12-31 15:55:42 and 2018-12-31 15:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:00:36 is within the specified time ranges, at index 81 amongst the possible time periods data. ie. btw 2018-12-31 15:58:42 and 2018-12-31 16:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:03:04 is within the specified time ranges, at index 82 amongst the possible time periods data. ie. btw 2018-12-31 16:01:42 and 2018-12-31 16:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:05:33 is within the specified time ranges, at index 83 amongst the possible time periods data. ie. btw 2018-12-31 16:04:42 and 2018-12-31 16:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:10:30 is within the specified time ranges, at index 84 amongst the possible time periods data. ie. btw 2018-12-31 16:07:42 and 2018-12-31 16:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:12:59 is within the specified time ranges, at index 85 amongst the possible time periods data. ie. btw 2018-12-31 16:10:42 and 2018-12-31 16:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:15:27 is within the specified time ranges, at index 86 amongst the possible time periods data. ie. btw 2018-12-31 16:13:42 and 2018-12-31 16:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:17:56 is within the specified time ranges, at index 87 amongst the possible time periods data. ie. btw 2018-12-31 16:16:42 and 2018-12-31 16:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:22:53 is within the specified time ranges, at index 89 amongst the possible time periods data. ie. btw 2018-12-31 16:22:42 and 2018-12-31 16:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:25:21 is within the specified time ranges, at index 89 amongst the possible time periods data. ie. btw 2018-12-31 16:22:42 and 2018-12-31 16:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:27:50 is within the specified time ranges, at index 90 amongst the possible time periods data. ie. btw 2018-12-31 16:25:42 and 2018-12-31 16:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:30:18 is within the specified time ranges, at index 91 amongst the possible time periods data. ie. btw 2018-12-31 16:28:42 and 2018-12-31 16:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:32:47 is within the specified time ranges, at index 92 amongst the possible time periods data. ie. btw 2018-12-31 16:31:42 and 2018-12-31 16:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:40:46 is within the specified time ranges, at index 95 amongst the possible time periods data. ie. btw 2018-12-31 16:40:42 and 2018-12-31 16:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:43:15 is within the specified time ranges, at index 95 amongst the possible time periods data. ie. btw 2018-12-31 16:40:42 and 2018-12-31 16:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:45:43 is within the specified time ranges, at index 96 amongst the possible time periods data. ie. btw 2018-12-31 16:43:42 and 2018-12-31 16:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:48:12 is within the specified time ranges, at index 97 amongst the possible time periods data. ie. btw 2018-12-31 16:46:42 and 2018-12-31 16:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:50:41 is within the specified time ranges, at index 98 amongst the possible time periods data. ie. btw 2018-12-31 16:49:42 and 2018-12-31 16:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:55:38 is within the specified time ranges, at index 99 amongst the possible time periods data. ie. btw 2018-12-31 16:52:42 and 2018-12-31 16:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 16:58:06 is within the specified time ranges, at index 100 amongst the possible time periods data. ie. btw 2018-12-31 16:55:42 and 2018-12-31 16:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:00:34 is within the specified time ranges, at index 101 amongst the possible time periods data. ie. btw 2018-12-31 16:58:42 and 2018-12-31 17:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:03:03 is within the specified time ranges, at index 102 amongst the possible time periods data. ie. btw 2018-12-31 17:01:42 and 2018-12-31 17:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:08:00 is within the specified time ranges, at index 104 amongst the possible time periods data. ie. btw 2018-12-31 17:07:42 and 2018-12-31 17:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:10:28 is within the specified time ranges, at index 104 amongst the possible time periods data. ie. btw 2018-12-31 17:07:42 and 2018-12-31 17:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:12:57 is within the specified time ranges, at index 105 amongst the possible time periods data. ie. btw 2018-12-31 17:10:42 and 2018-12-31 17:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:15:25 is within the specified time ranges, at index 106 amongst the possible time periods data. ie. btw 2018-12-31 17:13:42 and 2018-12-31 17:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:17:54 is within the specified time ranges, at index 107 amongst the possible time periods data. ie. btw 2018-12-31 17:16:42 and 2018-12-31 17:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:22:51 is within the specified time ranges, at index 109 amongst the possible time periods data. ie. btw 2018-12-31 17:22:42 and 2018-12-31 17:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:25:19 is within the specified time ranges, at index 109 amongst the possible time periods data. ie. btw 2018-12-31 17:22:42 and 2018-12-31 17:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:27:48 is within the specified time ranges, at index 110 amongst the possible time periods data. ie. btw 2018-12-31 17:25:42 and 2018-12-31 17:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:30:16 is within the specified time ranges, at index 111 amongst the possible time periods data. ie. btw 2018-12-31 17:28:42 and 2018-12-31 17:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:32:45 is within the specified time ranges, at index 112 amongst the possible time periods data. ie. btw 2018-12-31 17:31:42 and 2018-12-31 17:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:40:10 is within the specified time ranges, at index 114 amongst the possible time periods data. ie. btw 2018-12-31 17:37:42 and 2018-12-31 17:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:42:39 is within the specified time ranges, at index 115 amongst the possible time periods data. ie. btw 2018-12-31 17:40:42 and 2018-12-31 17:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:45:07 is within the specified time ranges, at index 116 amongst the possible time periods data. ie. btw 2018-12-31 17:43:42 and 2018-12-31 17:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:47:36 is within the specified time ranges, at index 117 amongst the possible time periods data. ie. btw 2018-12-31 17:46:42 and 2018-12-31 17:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:52:33 is within the specified time ranges, at index 118 amongst the possible time periods data. ie. btw 2018-12-31 17:49:42 and 2018-12-31 17:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:55:02 is within the specified time ranges, at index 119 amongst the possible time periods data. ie. btw 2018-12-31 17:52:42 and 2018-12-31 17:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:57:30 is within the specified time ranges, at index 120 amongst the possible time periods data. ie. btw 2018-12-31 17:55:42 and 2018-12-31 17:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 17:59:59 is within the specified time ranges, at index 121 amongst the possible time periods data. ie. btw 2018-12-31 17:58:42 and 2018-12-31 18:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:04:58 is within the specified time ranges, at index 123 amongst the possible time periods data. ie. btw 2018-12-31 18:04:42 and 2018-12-31 18:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:07:26 is within the specified time ranges, at index 123 amongst the possible time periods data. ie. btw 2018-12-31 18:04:42 and 2018-12-31 18:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:09:55 is within the specified time ranges, at index 124 amongst the possible time periods data. ie. btw 2018-12-31 18:07:42 and 2018-12-31 18:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:12:23 is within the specified time ranges, at index 125 amongst the possible time periods data. ie. btw 2018-12-31 18:10:42 and 2018-12-31 18:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:14:52 is within the specified time ranges, at index 126 amongst the possible time periods data. ie. btw 2018-12-31 18:13:42 and 2018-12-31 18:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:19:49 is within the specified time ranges, at index 128 amongst the possible time periods data. ie. btw 2018-12-31 18:19:42 and 2018-12-31 18:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:22:18 is within the specified time ranges, at index 128 amongst the possible time periods data. ie. btw 2018-12-31 18:19:42 and 2018-12-31 18:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:24:46 is within the specified time ranges, at index 129 amongst the possible time periods data. ie. btw 2018-12-31 18:22:42 and 2018-12-31 18:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:27:15 is within the specified time ranges, at index 130 amongst the possible time periods data. ie. btw 2018-12-31 18:25:42 and 2018-12-31 18:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:29:43 is within the specified time ranges, at index 131 amongst the possible time periods data. ie. btw 2018-12-31 18:28:42 and 2018-12-31 18:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:34:40 is within the specified time ranges, at index 132 amongst the possible time periods data. ie. btw 2018-12-31 18:31:42 and 2018-12-31 18:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:37:09 is within the specified time ranges, at index 133 amongst the possible time periods data. ie. btw 2018-12-31 18:34:42 and 2018-12-31 18:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:39:37 is within the specified time ranges, at index 134 amongst the possible time periods data. ie. btw 2018-12-31 18:37:42 and 2018-12-31 18:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:42:07 is within the specified time ranges, at index 135 amongst the possible time periods data. ie. btw 2018-12-31 18:40:42 and 2018-12-31 18:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:44:36 is within the specified time ranges, at index 136 amongst the possible time periods data. ie. btw 2018-12-31 18:43:42 and 2018-12-31 18:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:49:33 is within the specified time ranges, at index 137 amongst the possible time periods data. ie. btw 2018-12-31 18:46:42 and 2018-12-31 18:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:52:01 is within the specified time ranges, at index 138 amongst the possible time periods data. ie. btw 2018-12-31 18:49:42 and 2018-12-31 18:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:54:39 is within the specified time ranges, at index 139 amongst the possible time periods data. ie. btw 2018-12-31 18:52:42 and 2018-12-31 18:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 18:57:33 is within the specified time ranges, at index 140 amongst the possible time periods data. ie. btw 2018-12-31 18:55:42 and 2018-12-31 18:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:00:03 is within the specified time ranges, at index 141 amongst the possible time periods data. ie. btw 2018-12-31 18:58:42 and 2018-12-31 19:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:02:32 is within the specified time ranges, at index 142 amongst the possible time periods data. ie. btw 2018-12-31 19:01:42 and 2018-12-31 19:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:07:30 is within the specified time ranges, at index 143 amongst the possible time periods data. ie. btw 2018-12-31 19:04:42 and 2018-12-31 19:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:10:01 is within the specified time ranges, at index 144 amongst the possible time periods data. ie. btw 2018-12-31 19:07:42 and 2018-12-31 19:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:12:30 is within the specified time ranges, at index 145 amongst the possible time periods data. ie. btw 2018-12-31 19:10:42 and 2018-12-31 19:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:14:59 is within the specified time ranges, at index 146 amongst the possible time periods data. ie. btw 2018-12-31 19:13:42 and 2018-12-31 19:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:19:56 is within the specified time ranges, at index 148 amongst the possible time periods data. ie. btw 2018-12-31 19:19:42 and 2018-12-31 19:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:22:25 is within the specified time ranges, at index 148 amongst the possible time periods data. ie. btw 2018-12-31 19:19:42 and 2018-12-31 19:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:24:53 is within the specified time ranges, at index 149 amongst the possible time periods data. ie. btw 2018-12-31 19:22:42 and 2018-12-31 19:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:27:22 is within the specified time ranges, at index 150 amongst the possible time periods data. ie. btw 2018-12-31 19:25:42 and 2018-12-31 19:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:29:50 is within the specified time ranges, at index 151 amongst the possible time periods data. ie. btw 2018-12-31 19:28:42 and 2018-12-31 19:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:34:47 is within the specified time ranges, at index 153 amongst the possible time periods data. ie. btw 2018-12-31 19:34:42 and 2018-12-31 19:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:37:16 is within the specified time ranges, at index 153 amongst the possible time periods data. ie. btw 2018-12-31 19:34:42 and 2018-12-31 19:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:39:44 is within the specified time ranges, at index 154 amongst the possible time periods data. ie. btw 2018-12-31 19:37:42 and 2018-12-31 19:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:42:13 is within the specified time ranges, at index 155 amongst the possible time periods data. ie. btw 2018-12-31 19:40:42 and 2018-12-31 19:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:44:41 is within the specified time ranges, at index 156 amongst the possible time periods data. ie. btw 2018-12-31 19:43:42 and 2018-12-31 19:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:49:38 is within the specified time ranges, at index 157 amongst the possible time periods data. ie. btw 2018-12-31 19:46:42 and 2018-12-31 19:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:52:07 is within the specified time ranges, at index 158 amongst the possible time periods data. ie. btw 2018-12-31 19:49:42 and 2018-12-31 19:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:54:35 is within the specified time ranges, at index 159 amongst the possible time periods data. ie. btw 2018-12-31 19:52:42 and 2018-12-31 19:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 19:57:04 is within the specified time ranges, at index 160 amongst the possible time periods data. ie. btw 2018-12-31 19:55:42 and 2018-12-31 19:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:02:01 is within the specified time ranges, at index 162 amongst the possible time periods data. ie. btw 2018-12-31 20:01:42 and 2018-12-31 20:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:04:29 is within the specified time ranges, at index 162 amongst the possible time periods data. ie. btw 2018-12-31 20:01:42 and 2018-12-31 20:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:06:58 is within the specified time ranges, at index 163 amongst the possible time periods data. ie. btw 2018-12-31 20:04:42 and 2018-12-31 20:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:09:26 is within the specified time ranges, at index 164 amongst the possible time periods data. ie. btw 2018-12-31 20:07:42 and 2018-12-31 20:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:11:55 is within the specified time ranges, at index 165 amongst the possible time periods data. ie. btw 2018-12-31 20:10:42 and 2018-12-31 20:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:16:52 is within the specified time ranges, at index 167 amongst the possible time periods data. ie. btw 2018-12-31 20:16:42 and 2018-12-31 20:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:19:20 is within the specified time ranges, at index 167 amongst the possible time periods data. ie. btw 2018-12-31 20:16:42 and 2018-12-31 20:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:21:49 is within the specified time ranges, at index 168 amongst the possible time periods data. ie. btw 2018-12-31 20:19:42 and 2018-12-31 20:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:24:18 is within the specified time ranges, at index 169 amongst the possible time periods data. ie. btw 2018-12-31 20:22:42 and 2018-12-31 20:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:26:48 is within the specified time ranges, at index 170 amongst the possible time periods data. ie. btw 2018-12-31 20:25:42 and 2018-12-31 20:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:31:46 is within the specified time ranges, at index 172 amongst the possible time periods data. ie. btw 2018-12-31 20:31:42 and 2018-12-31 20:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:34:15 is within the specified time ranges, at index 172 amongst the possible time periods data. ie. btw 2018-12-31 20:31:42 and 2018-12-31 20:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:36:43 is within the specified time ranges, at index 173 amongst the possible time periods data. ie. btw 2018-12-31 20:34:42 and 2018-12-31 20:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:39:12 is within the specified time ranges, at index 174 amongst the possible time periods data. ie. btw 2018-12-31 20:37:42 and 2018-12-31 20:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:41:40 is within the specified time ranges, at index 175 amongst the possible time periods data. ie. btw 2018-12-31 20:40:42 and 2018-12-31 20:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:46:37 is within the specified time ranges, at index 176 amongst the possible time periods data. ie. btw 2018-12-31 20:43:42 and 2018-12-31 20:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:49:06 is within the specified time ranges, at index 177 amongst the possible time periods data. ie. btw 2018-12-31 20:46:42 and 2018-12-31 20:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:51:34 is within the specified time ranges, at index 178 amongst the possible time periods data. ie. btw 2018-12-31 20:49:42 and 2018-12-31 20:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:54:03 is within the specified time ranges, at index 179 amongst the possible time periods data. ie. btw 2018-12-31 20:52:42 and 2018-12-31 20:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 20:59:00 is within the specified time ranges, at index 181 amongst the possible time periods data. ie. btw 2018-12-31 20:58:42 and 2018-12-31 21:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:01:28 is within the specified time ranges, at index 181 amongst the possible time periods data. ie. btw 2018-12-31 20:58:42 and 2018-12-31 21:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:03:57 is within the specified time ranges, at index 182 amongst the possible time periods data. ie. btw 2018-12-31 21:01:42 and 2018-12-31 21:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:06:26 is within the specified time ranges, at index 183 amongst the possible time periods data. ie. btw 2018-12-31 21:04:42 and 2018-12-31 21:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:08:54 is within the specified time ranges, at index 184 amongst the possible time periods data. ie. btw 2018-12-31 21:07:42 and 2018-12-31 21:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:13:54 is within the specified time ranges, at index 186 amongst the possible time periods data. ie. btw 2018-12-31 21:13:42 and 2018-12-31 21:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:16:28 is within the specified time ranges, at index 186 amongst the possible time periods data. ie. btw 2018-12-31 21:13:42 and 2018-12-31 21:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:18:57 is within the specified time ranges, at index 187 amongst the possible time periods data. ie. btw 2018-12-31 21:16:42 and 2018-12-31 21:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:21:25 is within the specified time ranges, at index 188 amongst the possible time periods data. ie. btw 2018-12-31 21:19:42 and 2018-12-31 21:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:23:54 is within the specified time ranges, at index 189 amongst the possible time periods data. ie. btw 2018-12-31 21:22:42 and 2018-12-31 21:25:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:28:51 is within the specified time ranges, at index 191 amongst the possible time periods data. ie. btw 2018-12-31 21:28:42 and 2018-12-31 21:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:31:19 is within the specified time ranges, at index 191 amongst the possible time periods data. ie. btw 2018-12-31 21:28:42 and 2018-12-31 21:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:33:48 is within the specified time ranges, at index 192 amongst the possible time periods data. ie. btw 2018-12-31 21:31:42 and 2018-12-31 21:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:36:16 is within the specified time ranges, at index 193 amongst the possible time periods data. ie. btw 2018-12-31 21:34:42 and 2018-12-31 21:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:38:45 is within the specified time ranges, at index 194 amongst the possible time periods data. ie. btw 2018-12-31 21:37:42 and 2018-12-31 21:40:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:43:44 is within the specified time ranges, at index 196 amongst the possible time periods data. ie. btw 2018-12-31 21:43:42 and 2018-12-31 21:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:46:13 is within the specified time ranges, at index 196 amongst the possible time periods data. ie. btw 2018-12-31 21:43:42 and 2018-12-31 21:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:48:42 is within the specified time ranges, at index 197 amongst the possible time periods data. ie. btw 2018-12-31 21:46:42 and 2018-12-31 21:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:51:10 is within the specified time ranges, at index 198 amongst the possible time periods data. ie. btw 2018-12-31 21:49:42 and 2018-12-31 21:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:53:41 is within the specified time ranges, at index 199 amongst the possible time periods data. ie. btw 2018-12-31 21:52:42 and 2018-12-31 21:55:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 21:58:38 is within the specified time ranges, at index 200 amongst the possible time periods data. ie. btw 2018-12-31 21:55:42 and 2018-12-31 21:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:01:06 is within the specified time ranges, at index 201 amongst the possible time periods data. ie. btw 2018-12-31 21:58:42 and 2018-12-31 22:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:03:37 is within the specified time ranges, at index 202 amongst the possible time periods data. ie. btw 2018-12-31 22:01:42 and 2018-12-31 22:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:06:05 is within the specified time ranges, at index 203 amongst the possible time periods data. ie. btw 2018-12-31 22:04:42 and 2018-12-31 22:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:08:34 is within the specified time ranges, at index 204 amongst the possible time periods data. ie. btw 2018-12-31 22:07:42 and 2018-12-31 22:10:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:13:31 is within the specified time ranges, at index 205 amongst the possible time periods data. ie. btw 2018-12-31 22:10:42 and 2018-12-31 22:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:16:00 is within the specified time ranges, at index 206 amongst the possible time periods data. ie. btw 2018-12-31 22:13:42 and 2018-12-31 22:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:18:28 is within the specified time ranges, at index 207 amongst the possible time periods data. ie. btw 2018-12-31 22:16:42 and 2018-12-31 22:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:20:57 is within the specified time ranges, at index 208 amongst the possible time periods data. ie. btw 2018-12-31 22:19:42 and 2018-12-31 22:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:25:54 is within the specified time ranges, at index 210 amongst the possible time periods data. ie. btw 2018-12-31 22:25:42 and 2018-12-31 22:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:28:24 is within the specified time ranges, at index 210 amongst the possible time periods data. ie. btw 2018-12-31 22:25:42 and 2018-12-31 22:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:30:53 is within the specified time ranges, at index 211 amongst the possible time periods data. ie. btw 2018-12-31 22:28:42 and 2018-12-31 22:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:33:22 is within the specified time ranges, at index 212 amongst the possible time periods data. ie. btw 2018-12-31 22:31:42 and 2018-12-31 22:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:35:51 is within the specified time ranges, at index 213 amongst the possible time periods data. ie. btw 2018-12-31 22:34:42 and 2018-12-31 22:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:40:48 is within the specified time ranges, at index 215 amongst the possible time periods data. ie. btw 2018-12-31 22:40:42 and 2018-12-31 22:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:43:16 is within the specified time ranges, at index 215 amongst the possible time periods data. ie. btw 2018-12-31 22:40:42 and 2018-12-31 22:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:45:45 is within the specified time ranges, at index 216 amongst the possible time periods data. ie. btw 2018-12-31 22:43:42 and 2018-12-31 22:46:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:48:14 is within the specified time ranges, at index 217 amongst the possible time periods data. ie. btw 2018-12-31 22:46:42 and 2018-12-31 22:49:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:51:03 is within the specified time ranges, at index 218 amongst the possible time periods data. ie. btw 2018-12-31 22:49:42 and 2018-12-31 22:52:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:56:00 is within the specified time ranges, at index 220 amongst the possible time periods data. ie. btw 2018-12-31 22:55:42 and 2018-12-31 22:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 22:58:29 is within the specified time ranges, at index 220 amongst the possible time periods data. ie. btw 2018-12-31 22:55:42 and 2018-12-31 22:58:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:00:57 is within the specified time ranges, at index 221 amongst the possible time periods data. ie. btw 2018-12-31 22:58:42 and 2018-12-31 23:01:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:03:28 is within the specified time ranges, at index 222 amongst the possible time periods data. ie. btw 2018-12-31 23:01:42 and 2018-12-31 23:04:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:05:57 is within the specified time ranges, at index 223 amongst the possible time periods data. ie. btw 2018-12-31 23:04:42 and 2018-12-31 23:07:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:10:54 is within the specified time ranges, at index 225 amongst the possible time periods data. ie. btw 2018-12-31 23:10:42 and 2018-12-31 23:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:13:23 is within the specified time ranges, at index 225 amongst the possible time periods data. ie. btw 2018-12-31 23:10:42 and 2018-12-31 23:13:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:15:53 is within the specified time ranges, at index 226 amongst the possible time periods data. ie. btw 2018-12-31 23:13:42 and 2018-12-31 23:16:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:18:21 is within the specified time ranges, at index 227 amongst the possible time periods data. ie. btw 2018-12-31 23:16:42 and 2018-12-31 23:19:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:20:50 is within the specified time ranges, at index 228 amongst the possible time periods data. ie. btw 2018-12-31 23:19:42 and 2018-12-31 23:22:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:25:50 is within the specified time ranges, at index 230 amongst the possible time periods data. ie. btw 2018-12-31 23:25:42 and 2018-12-31 23:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:28:18 is within the specified time ranges, at index 230 amongst the possible time periods data. ie. btw 2018-12-31 23:25:42 and 2018-12-31 23:28:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:30:47 is within the specified time ranges, at index 231 amongst the possible time periods data. ie. btw 2018-12-31 23:28:42 and 2018-12-31 23:31:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:33:15 is within the specified time ranges, at index 232 amongst the possible time periods data. ie. btw 2018-12-31 23:31:42 and 2018-12-31 23:34:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:35:44 is within the specified time ranges, at index 233 amongst the possible time periods data. ie. btw 2018-12-31 23:34:42 and 2018-12-31 23:37:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:43:11 is within the specified time ranges, at index 235 amongst the possible time periods data. ie. btw 2018-12-31 23:40:42 and 2018-12-31 23:43:42
#  -- -- -- -- YAY! the current timestamp ( 2018-12-31 23:45:48 is within the specified time ranges, at index 236 amongst the possible time periods data. ie. btw 2018-12-31 23:43:42 and 2018-12-31 23:46:42
# ...
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 04:39:11 is within the specified time ranges, at index 334 amongst the possible time periods data. ie. btw 2019-01-01 04:37:42 and 2019-01-01 04:40:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 04:41:38 is within the specified time ranges, at index 335 amongst the possible time periods data. ie. btw 2019-01-01 04:40:42 and 2019-01-01 04:43:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 04:46:33 is within the specified time ranges, at index 336 amongst the possible time periods data. ie. btw 2019-01-01 04:43:42 and 2019-01-01 04:46:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 04:49:01 is within the specified time ranges, at index 337 amongst the possible time periods data. ie. btw 2019-01-01 04:46:42 and 2019-01-01 04:49:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 04:51:28 is within the specified time ranges, at index 338 amongst the possible time periods data. ie. btw 2019-01-01 04:49:42 and 2019-01-01 04:52:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 04:53:56 is within the specified time ranges, at index 339 amongst the possible time periods data. ie. btw 2019-01-01 04:52:42 and 2019-01-01 04:55:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 04:58:51 is within the specified time ranges, at index 341 amongst the possible time periods data. ie. btw 2019-01-01 04:58:42 and 2019-01-01 05:01:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:01:18 is within the specified time ranges, at index 341 amongst the possible time periods data. ie. btw 2019-01-01 04:58:42 and 2019-01-01 05:01:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:03:46 is within the specified time ranges, at index 342 amongst the possible time periods data. ie. btw 2019-01-01 05:01:42 and 2019-01-01 05:04:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:06:13 is within the specified time ranges, at index 343 amongst the possible time periods data. ie. btw 2019-01-01 05:04:42 and 2019-01-01 05:07:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:08:41 is within the specified time ranges, at index 344 amongst the possible time periods data. ie. btw 2019-01-01 05:07:42 and 2019-01-01 05:10:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:13:36 is within the specified time ranges, at index 345 amongst the possible time periods data. ie. btw 2019-01-01 05:10:42 and 2019-01-01 05:13:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:16:03 is within the specified time ranges, at index 346 amongst the possible time periods data. ie. btw 2019-01-01 05:13:42 and 2019-01-01 05:16:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:18:30 is within the specified time ranges, at index 347 amongst the possible time periods data. ie. btw 2019-01-01 05:16:42 and 2019-01-01 05:19:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:20:58 is within the specified time ranges, at index 348 amongst the possible time periods data. ie. btw 2019-01-01 05:19:42 and 2019-01-01 05:22:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:25:53 is within the specified time ranges, at index 350 amongst the possible time periods data. ie. btw 2019-01-01 05:25:42 and 2019-01-01 05:28:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:28:20 is within the specified time ranges, at index 350 amongst the possible time periods data. ie. btw 2019-01-01 05:25:42 and 2019-01-01 05:28:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:30:48 is within the specified time ranges, at index 351 amongst the possible time periods data. ie. btw 2019-01-01 05:28:42 and 2019-01-01 05:31:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:33:15 is within the specified time ranges, at index 352 amongst the possible time periods data. ie. btw 2019-01-01 05:31:42 and 2019-01-01 05:34:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:35:43 is within the specified time ranges, at index 353 amongst the possible time periods data. ie. btw 2019-01-01 05:34:42 and 2019-01-01 05:37:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:40:38 is within the specified time ranges, at index 354 amongst the possible time periods data. ie. btw 2019-01-01 05:37:42 and 2019-01-01 05:40:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:43:05 is within the specified time ranges, at index 355 amongst the possible time periods data. ie. btw 2019-01-01 05:40:42 and 2019-01-01 05:43:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:45:33 is within the specified time ranges, at index 356 amongst the possible time periods data. ie. btw 2019-01-01 05:43:42 and 2019-01-01 05:46:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:48:00 is within the specified time ranges, at index 357 amongst the possible time periods data. ie. btw 2019-01-01 05:46:42 and 2019-01-01 05:49:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:52:55 is within the specified time ranges, at index 359 amongst the possible time periods data. ie. btw 2019-01-01 05:52:42 and 2019-01-01 05:55:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:55:23 is within the specified time ranges, at index 359 amongst the possible time periods data. ie. btw 2019-01-01 05:52:42 and 2019-01-01 05:55:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 05:57:50 is within the specified time ranges, at index 360 amongst the possible time periods data. ie. btw 2019-01-01 05:55:42 and 2019-01-01 05:58:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:00:18 is within the specified time ranges, at index 361 amongst the possible time periods data. ie. btw 2019-01-01 05:58:42 and 2019-01-01 06:01:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:02:45 is within the specified time ranges, at index 362 amongst the possible time periods data. ie. btw 2019-01-01 06:01:42 and 2019-01-01 06:04:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:07:40 is within the specified time ranges, at index 363 amongst the possible time periods data. ie. btw 2019-01-01 06:04:42 and 2019-01-01 06:07:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:10:08 is within the specified time ranges, at index 364 amongst the possible time periods data. ie. btw 2019-01-01 06:07:42 and 2019-01-01 06:10:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:12:35 is within the specified time ranges, at index 365 amongst the possible time periods data. ie. btw 2019-01-01 06:10:42 and 2019-01-01 06:13:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:15:03 is within the specified time ranges, at index 366 amongst the possible time periods data. ie. btw 2019-01-01 06:13:42 and 2019-01-01 06:16:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:19:58 is within the specified time ranges, at index 368 amongst the possible time periods data. ie. btw 2019-01-01 06:19:42 and 2019-01-01 06:22:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:22:25 is within the specified time ranges, at index 368 amongst the possible time periods data. ie. btw 2019-01-01 06:19:42 and 2019-01-01 06:22:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:24:53 is within the specified time ranges, at index 369 amongst the possible time periods data. ie. btw 2019-01-01 06:22:42 and 2019-01-01 06:25:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:27:20 is within the specified time ranges, at index 370 amongst the possible time periods data. ie. btw 2019-01-01 06:25:42 and 2019-01-01 06:28:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:29:48 is within the specified time ranges, at index 371 amongst the possible time periods data. ie. btw 2019-01-01 06:28:42 and 2019-01-01 06:31:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:34:43 is within the specified time ranges, at index 373 amongst the possible time periods data. ie. btw 2019-01-01 06:34:42 and 2019-01-01 06:37:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:37:10 is within the specified time ranges, at index 373 amongst the possible time periods data. ie. btw 2019-01-01 06:34:42 and 2019-01-01 06:37:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:39:38 is within the specified time ranges, at index 374 amongst the possible time periods data. ie. btw 2019-01-01 06:37:42 and 2019-01-01 06:40:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:42:05 is within the specified time ranges, at index 375 amongst the possible time periods data. ie. btw 2019-01-01 06:40:42 and 2019-01-01 06:43:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:47:00 is within the specified time ranges, at index 377 amongst the possible time periods data. ie. btw 2019-01-01 06:46:42 and 2019-01-01 06:49:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:49:27 is within the specified time ranges, at index 377 amongst the possible time periods data. ie. btw 2019-01-01 06:46:42 and 2019-01-01 06:49:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:51:55 is within the specified time ranges, at index 378 amongst the possible time periods data. ie. btw 2019-01-01 06:49:42 and 2019-01-01 06:52:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:54:22 is within the specified time ranges, at index 379 amongst the possible time periods data. ie. btw 2019-01-01 06:52:42 and 2019-01-01 06:55:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:56:50 is within the specified time ranges, at index 380 amongst the possible time periods data. ie. btw 2019-01-01 06:55:42 and 2019-01-01 06:58:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 06:59:17 is within the specified time ranges, at index 381 amongst the possible time periods data. ie. btw 2019-01-01 06:58:42 and 2019-01-01 07:01:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:04:49 is within the specified time ranges, at index 383 amongst the possible time periods data. ie. btw 2019-01-01 07:04:42 and 2019-01-01 07:07:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:07:33 is within the specified time ranges, at index 383 amongst the possible time periods data. ie. btw 2019-01-01 07:04:42 and 2019-01-01 07:07:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:09:53 is within the specified time ranges, at index 384 amongst the possible time periods data. ie. btw 2019-01-01 07:07:42 and 2019-01-01 07:10:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:12:20 is within the specified time ranges, at index 385 amongst the possible time periods data. ie. btw 2019-01-01 07:10:42 and 2019-01-01 07:13:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:14:48 is within the specified time ranges, at index 386 amongst the possible time periods data. ie. btw 2019-01-01 07:13:42 and 2019-01-01 07:16:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:19:43 is within the specified time ranges, at index 388 amongst the possible time periods data. ie. btw 2019-01-01 07:19:42 and 2019-01-01 07:22:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:22:10 is within the specified time ranges, at index 388 amongst the possible time periods data. ie. btw 2019-01-01 07:19:42 and 2019-01-01 07:22:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:27:05 is within the specified time ranges, at index 390 amongst the possible time periods data. ie. btw 2019-01-01 07:25:42 and 2019-01-01 07:28:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:32:00 is within the specified time ranges, at index 392 amongst the possible time periods data. ie. btw 2019-01-01 07:31:42 and 2019-01-01 07:34:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:34:27 is within the specified time ranges, at index 392 amongst the possible time periods data. ie. btw 2019-01-01 07:31:42 and 2019-01-01 07:34:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:36:55 is within the specified time ranges, at index 393 amongst the possible time periods data. ie. btw 2019-01-01 07:34:42 and 2019-01-01 07:37:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:36:55 is within the specified time ranges, at index 393 amongst the possible time periods data. ie. btw 2019-01-01 07:34:42 and 2019-01-01 07:37:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:42:09 is within the specified time ranges, at index 395 amongst the possible time periods data. ie. btw 2019-01-01 07:40:42 and 2019-01-01 07:43:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:44:37 is within the specified time ranges, at index 396 amongst the possible time periods data. ie. btw 2019-01-01 07:43:42 and 2019-01-01 07:46:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:49:32 is within the specified time ranges, at index 397 amongst the possible time periods data. ie. btw 2019-01-01 07:46:42 and 2019-01-01 07:49:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:51:59 is within the specified time ranges, at index 398 amongst the possible time periods data. ie. btw 2019-01-01 07:49:42 and 2019-01-01 07:52:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:54:27 is within the specified time ranges, at index 399 amongst the possible time periods data. ie. btw 2019-01-01 07:52:42 and 2019-01-01 07:55:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 07:56:54 is within the specified time ranges, at index 400 amongst the possible time periods data. ie. btw 2019-01-01 07:55:42 and 2019-01-01 07:58:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:01:50 is within the specified time ranges, at index 402 amongst the possible time periods data. ie. btw 2019-01-01 08:01:42 and 2019-01-01 08:04:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:04:20 is within the specified time ranges, at index 402 amongst the possible time periods data. ie. btw 2019-01-01 08:01:42 and 2019-01-01 08:04:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:06:47 is within the specified time ranges, at index 403 amongst the possible time periods data. ie. btw 2019-01-01 08:04:42 and 2019-01-01 08:07:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:09:15 is within the specified time ranges, at index 404 amongst the possible time periods data. ie. btw 2019-01-01 08:07:42 and 2019-01-01 08:10:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:11:42 is within the specified time ranges, at index 405 amongst the possible time periods data. ie. btw 2019-01-01 08:10:42 and 2019-01-01 08:13:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:16:37 is within the specified time ranges, at index 406 amongst the possible time periods data. ie. btw 2019-01-01 08:13:42 and 2019-01-01 08:16:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:19:04 is within the specified time ranges, at index 407 amongst the possible time periods data. ie. btw 2019-01-01 08:16:42 and 2019-01-01 08:19:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:21:32 is within the specified time ranges, at index 408 amongst the possible time periods data. ie. btw 2019-01-01 08:19:42 and 2019-01-01 08:22:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:23:59 is within the specified time ranges, at index 409 amongst the possible time periods data. ie. btw 2019-01-01 08:22:42 and 2019-01-01 08:25:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:28:54 is within the specified time ranges, at index 411 amongst the possible time periods data. ie. btw 2019-01-01 08:28:42 and 2019-01-01 08:31:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:31:22 is within the specified time ranges, at index 411 amongst the possible time periods data. ie. btw 2019-01-01 08:28:42 and 2019-01-01 08:31:42
#  -- -- -- -- YAY! the current timestamp ( 2019-01-01 08:33:49 is within the specified time ranges, at index 412 amongst the possible time periods data. ie. btw 2019-01-01 08:31:42 and 2019-01-01 08:34:42

# %%
curr_sensor_measurements_for_all_time_periods

# %%
len( out_array_w_generated_periodic_data_arrays )

# %%
out_array_w_generated_periodic_data_arrays

# %%
( 1546257522000000000 - 1546257522000000001 )

# %%
curr_val = 1546257522000000000
curr_val - 1546257522000000001

# %%
1546257522000000000
1546257522000000001
1546257522000000000 # curr val

# %%
1546257522000000000
1546257702000000000
1546257524000000000 # curr val

# %%
( 1546257522000000000 - 1546257702000000000 ) / ( 10**9 )

# %%
1546257522000000000
1546257702000000000
1546257527000000000 # current value

# %%
1546257522000000000 - 1546257702000000000, ( 1546257522000000000 - 1546257702000000000 ) / ( 10**9 )

# %%
# Remains from previous test

# %%
# temporary storage location for out arrays 
out_array_w_generated_periodic_data_arrays = []

# prepare the out array, beforhand
## curr_sensor_measurements_for_all_time_periods = np.zeros( data_sampling_windows__time_periods.shape[0] )

curr_sensor_id_i = 0

starttime = time.time() 

# Loop through the different sensor ( numbers )
for sensor_id_ in unique_sensor_ids[:1]:
    print("-- working on sensor id "+str( sensor_id_ )+" |  "+str( curr_sensor_id_i )+"/"+str( unique_sensor_ids.shape[0] )  )
    curr_sensor_id_i = curr_sensor_id_i + 1
    
    # fetch the measurements for this sensor id
    curr_sensor_id_measurements = relev_time_period[ relev_time_period['sensor_id'] == sensor_id_  ]
    
    # sort them by time 
    curr_sensor_id_measurements = curr_sensor_id_measurements.sort_values( by=['timestamp'] ) 
    ## print("--- current sensor id has "+str( curr_sensor_id_measurements.shape[0])+" measurements" )
    
    #curr_sensor_id_measurements__only_timestamps = curr_sensor_id_measurements['timestamp']
    ## now with epoch
    curr_sensor_id_measurements__only_timestamps = in_data__with_epoch_times['timestamp']
    curr_sensor_id_measurements__only_p1_vals = curr_sensor_id_measurements['p1']
    curr_sensor_id_measurements__only_p2_vals = curr_sensor_id_measurements['p2']
    
    # -- make sure all the measurements of the given time period are there
    
    # make an array with enough slots for all time periods
    curr_sensor_measurements_for_all_time_periods = np.zeros( data_sampling_windows__time_periods__as_epoch_times.shape[0] )
    ## print(" --- curr_sensor_measurements_for_all_time_periods.shape = "+str( curr_sensor_measurements_for_all_time_periods.shape ))
    ## print( curr_sensor_measurements_for_all_time_periods )
    
    # loop through all values in the data 
    for curr_sensor_measurements_row_i in range( curr_sensor_id_measurements__only_timestamps.shape[0] ):
    ### for curr_sensor_measurements_row_i in range( 20 ):
    
        print("\n -- -- working on measurement #"+str( curr_sensor_measurements_row_i )+" (pm2.5/10  : "+str(curr_sensor_id_measurements__only_p1_vals.iloc[ curr_sensor_measurements_row_i]) ) 
        # print("\t\t /"+str(curr_sensor_id_measurements__only_p2_vals[ curr_sensor_measurements_row_i]) )
        # print( "\t\t ) - with timestamp "+str( curr_sensor_id_measurements__only_timestamps.iloc[ curr_sensor_measurements_row_i ] ) )
        
        # loop through the available timestamps, and see whether the current time stamp
        # is within these. 
        # - if it is, then insert it at the appropiate current index 
        # in the out array
        
        # optimisation variable to remember where the last 
        # value was found, in time
        # - the idea is that we start the next search in time indicies, 
        #   only after the last found position, so we can skip checking the previous positions 
        last_found_time_index = 0 
        
        # note the optimisation above and below 
        for all_relev_timestamps_array__current_index in range( last_found_time_index, data_sampling_windows__time_periods__as_epoch_times.shape[0]-1 ):
        ### unoptimised edition : 
        ### for all_relev_timestamps_array__current_index in range( data_sampling_windows__time_periods__as_epoch_times.shape[0]-1 ):
        ### for all_relev_timestamps_array__current_index in range( 100 ):
        
            ### print("-- -- -- looping through available timestamps - loooking at index #"+str( all_relev_timestamps_array__current_index )+" : timestamp "+str( data_sampling_windows__time_periods__as_epoch_times[ all_relev_timestamps_array__current_index ] ))
        
        #
            if curr_sensor_id_measurements__only_timestamps[ curr_sensor_measurements_row_i ] > data_sampling_windows__time_periods__as_epoch_times[ all_relev_timestamps_array__current_index ] and curr_sensor_id_measurements__only_timestamps[ curr_sensor_measurements_row_i ] < data_sampling_windows__time_periods__as_epoch_times[ all_relev_timestamps_array__current_index +1 ] :
                
                print( " -- -- -- -- YAY! the current timestamp ( "+str(  curr_sensor_id_measurements__only_timestamps[ curr_sensor_measurements_row_i ]  ) )
                print( "\t\t\t\t is within the specified time ranges, at index "+str( all_relev_timestamps_array__current_index ) )
                print( "\t\t\t\t amongst the possible time periods data. ie. btw "+str( data_sampling_windows__time_periods__as_epoch_times[ all_relev_timestamps_array__current_index ]) )
                print( "\t\t\t\t and "+str( data_sampling_windows__time_periods__as_epoch_times[ all_relev_timestamps_array__current_index +1 ] ) )
        
                # assign the current PM value as appropriate 
                curr_sensor_measurements_for_all_time_periods[ all_relev_timestamps_array__current_index ] = curr_sensor_id_measurements__only_p1_vals.iloc[ curr_sensor_measurements_row_i ]
                
                # set the variable suggesting which position 
                # the timestamp was found in, 
                # and which position the next search should start from 
                last_found_time_index = all_relev_timestamps_array__current_index
                
                #
                # no need to continue finding possible time slots - just break
                break
                
    # END OF DIFFERENT SENSOR LOOPING
    # print the resulting values slotted array - ie array with slots 
    # for values, formatted according to time slots
    ## print( " <<< resulting periodic values array : ")
    ## print( curr_sensor_measurements_for_all_time_periods )
    out_array_w_generated_periodic_data_arrays.append( curr_sensor_measurements_for_all_time_periods )
                
# ende
print( "- done after "+str( time.time() - starttime )+" seconds " )

# %%
test_data = in_data['timestamp']

# %%
# %timeit test_data.iat[0]

# %%
# %timeit test_data.iloc[0]

# %%
in_data = in_data[1:]

# %%
in_data

# %%
in_data_timestamps_only = in_data2['timestamp']

# %%
type( in_data_timestamps_only )

# %%
in_data_timestamps_only

# %%
in_data_timestamps_only__numpy_array_edition = np.array( in_data_timestamps_only )

# %%
in_data_timestamps_only__numpy_array_edition

# %%
type( test_nump_array ), type( test_data )

# %%
# %timeit in_data_timestamps_only__numpy_array_edition[0] = -11

# %%
out_at_given_len = np.array( np.zeros(10) )

# %%
out_at_given_len
