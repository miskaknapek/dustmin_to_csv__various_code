# %% [markdown]
# # Luftdaten data : data cleaning, resampling - mini version
# ## Code builds a continuous time tabular version of the luftdaen data, such that the same time period is present for each sensor in the data, regardless of whether each sensor has data for all the time slots.
#
# ## Testing :
# - using pd.resample
# - constructing a time shift using pandas own tools, rather than my own

# %% [markdown]
# #### Reference documents
#
# Resampling time series data with Pandas ( Ben Alex Keen )
# http://benalexkeen.com/resampling-time-series-data-with-pandas/

# %%
import pandas as pd
import numpy as np
import time

# %%
# parameters

# start_time = "2018-12-31 21:58:42"
end_time = "2019-01-01 11:58:42"
# generate this please
start_time = "?????"

time_frequency_for_periods__for_basic_data = "5T"
num_of_time_periods___for_basic_data = 24*20 # 24 hrs * 12 x 5 mins in each hour

# when generating time periods 
sampling_frequency = "3T"



# --- data urls 

curr_url = "????"
nordic_midnight_24_hrs_data__url = "/Users/miska/Documents/open_something/luftdaten/luftdaten_code/luftdaten__make_tabular_data__from_db_data/ld_NYE_midnight_24hrs_nordics_all_data_01.csv"

# set the current data source 
curr_url =nordic_midnight_24_hrs_data__url

# %%
# try convert the timestamp in the data, to epoch

in_data = pd.read_csv( curr_url )
in_data.shape
# Out:
# (127109, 7)

# %%
in_data.dtypes
# Out:
# sensor_id         int64
# sensor_namee     object
# lat             float64
# lon             float64
# timestamp        object
# p1              float64
# p2              float64
# dtype: object

# %%
in_data['timestamp'] = pd.to_datetime( in_data['timestamp'] )

# %%
in_data.dtypes
# Out:
# sensor_id                int64
# sensor_namee            object
# lat                    float64
# lon                    float64
# timestamp       datetime64[ns]
# p1                     float64
# p2                     float64
# dtype: object

# %%
in_data.head()
# Out:
#    sensor_id sensor_namee     lat     lon           timestamp      p1     p2
# 0       7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43   1.56
# 1       7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77  33.82
# 2       7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48   2.47
# 3       7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05   6.62
# 4       7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78   1.02

# %%
in_data.tail()
# Out:
#         sensor_id sensor_namee     lat     lon           timestamp     p1  \
# 127104      16723       SDS011  57.736  11.894 2019-01-01 11:58:57  16.47
# 127105      16815       SDS011  59.462  18.040 2019-01-01 11:59:36   2.67
# 127106      17235       SDS011  59.272  17.780 2019-01-01 11:59:41   4.69
# 127107      10588       SDS011  55.676  13.346 2019-01-01 11:57:12  14.08
# 127108      10647       SDS011  55.608  13.036 2019-01-01 11:58:42  23.42
#
#           p2
# 127104  3.40
# 127105  1.97
# 127106  1.82
# 127107  3.68
# 127108  4.75

# %%
in_data__with_epoch_times = in_data.copy()

# %%
in_data__with_epoch_times['timestamp'] = in_data['timestamp'].astype( 'int64' )

# %%
in_data__with_epoch_times.head()
# Out:
#    sensor_id sensor_namee     lat     lon            timestamp      p1     p2
# 0       7273       SDS011  60.002  17.846  1546257442000000000    3.43   1.56
# 1       7275       SDS011  57.720  11.888  1546257524000000000  482.77  33.82
# 2       7277       SDS011  59.266  15.230  1546257527000000000    5.48   2.47
# 3       7406       SDS011  56.964  24.128  1546257401000000000   11.05   6.62
# 4       7428       SDS011  59.868  17.624  1546257462000000000    1.78   1.02

# %%
in_data__with_epoch_times.tail()
# Out:
#         sensor_id sensor_namee     lat     lon            timestamp     p1  \
# 127104      16723       SDS011  57.736  11.894  1546343937000000000  16.47
# 127105      16815       SDS011  59.462  18.040  1546343976000000000   2.67
# 127106      17235       SDS011  59.272  17.780  1546343981000000000   4.69
# 127107      10588       SDS011  55.676  13.346  1546343832000000000  14.08
# 127108      10647       SDS011  55.608  13.036  1546343922000000000  23.42
#
#           p2
# 127104  3.40
# 127105  1.97
# 127106  1.82
# 127107  3.68
# 127108  4.75

# %%
# test access to timestamps 
in_data__with_epoch_times__ONLY_TIMESTAMPS = in_data__with_epoch_times['timestamp']
in_data__with_epoch_times__ONLY_TIMESTAMPS.shape
# Out:
# (127109,)

# %%
type( in_data__with_epoch_times__ONLY_TIMESTAMPS  )
# Out:
# pandas.core.series.Series

# %%
# testing how to access and element. 
# - seems a regular [] acess is fine 
in_data__with_epoch_times__ONLY_TIMESTAMPS[0]
# Out:
# 1546257442000000000

# %%
### various time operations

# %%
end_time
# Out:
# '2019-01-01 11:58:42'

# %% [markdown]
# ## Doing own time-series construction

# %% [markdown]
# ### : extending time-series arrays by cutting-pasting time arrays.

# %%
test_time_series = in_data
test_time_series.shape
# Out:
# (127109, 7)

# %%
data_from_start = test_time_series[:10]
data_from_start
# Out:
#    sensor_id sensor_namee     lat     lon           timestamp      p1     p2
# 0       7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43   1.56
# 1       7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77  33.82
# 2       7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48   2.47
# 3       7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05   6.62
# 4       7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78   1.02
# 5       7469       SDS011  56.944  24.142 2018-12-31 11:57:52    8.40   5.54
# 6       7597       SDS011  59.320  18.064 2018-12-31 11:58:51    3.68   2.00
# 7       8683       SDS011  59.744  18.206 2018-12-31 11:58:28    3.01   2.80
# 8       9411       SDS011  59.266  15.230 2018-12-31 11:57:18    3.44   2.18
# 9       9436       SDS011  59.334  18.034 2018-12-31 11:57:22    2.12   1.90

# %%
data_from_middle = test_time_series[60000:60010]
data_from_middle.head()
# Out:
#        sensor_id sensor_namee     lat     lon           timestamp    p1    p2
# 60000      12679       SDS011  59.384  17.874 2018-12-31 16:52:43  0.40  0.40
# 60001      12687       SDS011  59.388  17.798 2018-12-31 16:52:21  2.83  1.90
# 60002      12691       SDS011  57.636  18.304 2018-12-31 16:51:17  2.40  1.70
# 60003      12693       SDS011  58.190  12.720 2018-12-31 16:51:03  6.42  2.62
# 60004      14017       SDS011  59.376  18.010 2018-12-31 16:51:10  4.07  1.94

# %%
data_from_end = test_time_series[-10:]
data_from_end
# Out:
#         sensor_id sensor_namee     lat     lon           timestamp     p1  \
# 127099      13020       SDS011  57.722  11.948 2019-01-01 11:59:41  20.64
# 127100      16147       SDS011  59.364  18.018 2019-01-01 11:59:46   3.28
# 127101      16153       SDS011  55.648  13.208 2019-01-01 11:57:19  20.00
# 127102      16296       SDS011  56.144  13.394 2019-01-01 11:59:59  23.86
# 127103      16533       SDS011  55.722  13.202 2019-01-01 11:56:55  18.05
# 127104      16723       SDS011  57.736  11.894 2019-01-01 11:58:57  16.47
# 127105      16815       SDS011  59.462  18.040 2019-01-01 11:59:36   2.67
# 127106      17235       SDS011  59.272  17.780 2019-01-01 11:59:41   4.69
# 127107      10588       SDS011  55.676  13.346 2019-01-01 11:57:12  14.08
# 127108      10647       SDS011  55.608  13.036 2019-01-01 11:58:42  23.42
#
#           p2
# 127099  3.67
# 127100  1.80
# 127101  3.90
# 127102  7.45
# 127103  4.33
# 127104  3.40
# 127105  1.97
# 127106  1.82
# 127107  3.68
# 127108  4.75

# %% [markdown]
# ### let's try make an array, where we extend the time  by adding earlier and later times

# %%
middle_array_with_earlier_time = data_from_start.append( data_from_middle )

# %%
middle_array_with_earlier_time
# Out:
#        sensor_id sensor_namee     lat     lon           timestamp      p1  \
# 0           7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43
# 1           7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77
# 2           7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48
# 3           7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05
# 4           7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78
# 5           7469       SDS011  56.944  24.142 2018-12-31 11:57:52    8.40
# 6           7597       SDS011  59.320  18.064 2018-12-31 11:58:51    3.68
# 7           8683       SDS011  59.744  18.206 2018-12-31 11:58:28    3.01
# 8           9411       SDS011  59.266  15.230 2018-12-31 11:57:18    3.44
# 9           9436       SDS011  59.334  18.034 2018-12-31 11:57:22    2.12
# 60000      12679       SDS011  59.384  17.874 2018-12-31 16:52:43    0.40
# 60001      12687       SDS011  59.388  17.798 2018-12-31 16:52:21    2.83
# 60002      12691       SDS011  57.636  18.304 2018-12-31 16:51:17    2.40
# 60003      12693       SDS011  58.190  12.720 2018-12-31 16:51:03    6.42
# 60004      14017       SDS011  59.376  18.010 2018-12-31 16:51:10    4.07
# 60005      14133       SDS011  59.364  18.018 2018-12-31 16:50:49    4.14
# 60006      14209       SDS011  56.070  12.698 2018-12-31 16:51:35   28.52
# 60007      14264       SDS011  57.654  11.880 2018-12-31 16:51:51   26.92
# 60008      14276       SDS011  57.346  12.150 2018-12-31 16:50:46   72.48
# 60009      14278       SDS011  59.374  18.010 2018-12-31 16:51:31    4.64
#
#           p2
# 0       1.56
# 1      33.82
# 2       2.47
# 3       6.62
# 4       1.02
# 5       5.54
# 6       2.00
# 7       2.80
# 8       2.18
# 9       1.90
# 60000   0.40
# 60001   1.90
# 60002   1.70
# 60003   2.62
# 60004   1.94
# 60005   2.38
# 60006  13.48
# 60007   8.46
# 60008  20.16
# 60009   2.30

# %%
middle_array_with_earlier_and_later_added_times = middle_array_with_earlier_time.append( data_from_end )
middle_array_with_earlier_and_later_added_times
# Out:
#         sensor_id sensor_namee     lat     lon           timestamp      p1  \
# 0            7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43
# 1            7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77
# 2            7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48
# 3            7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05
# 4            7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78
# 5            7469       SDS011  56.944  24.142 2018-12-31 11:57:52    8.40
# 6            7597       SDS011  59.320  18.064 2018-12-31 11:58:51    3.68
# 7            8683       SDS011  59.744  18.206 2018-12-31 11:58:28    3.01
# 8            9411       SDS011  59.266  15.230 2018-12-31 11:57:18    3.44
# 9            9436       SDS011  59.334  18.034 2018-12-31 11:57:22    2.12
# 60000       12679       SDS011  59.384  17.874 2018-12-31 16:52:43    0.40
# 60001       12687       SDS011  59.388  17.798 2018-12-31 16:52:21    2.83
# 60002       12691       SDS011  57.636  18.304 2018-12-31 16:51:17    2.40
# 60003       12693       SDS011  58.190  12.720 2018-12-31 16:51:03    6.42
# 60004       14017       SDS011  59.376  18.010 2018-12-31 16:51:10    4.07
# 60005       14133       SDS011  59.364  18.018 2018-12-31 16:50:49    4.14
# 60006       14209       SDS011  56.070  12.698 2018-12-31 16:51:35   28.52
# 60007       14264       SDS011  57.654  11.880 2018-12-31 16:51:51   26.92
# 60008       14276       SDS011  57.346  12.150 2018-12-31 16:50:46   72.48
# 60009       14278       SDS011  59.374  18.010 2018-12-31 16:51:31    4.64
# 127099      13020       SDS011  57.722  11.948 2019-01-01 11:59:41   20.64
# 127100      16147       SDS011  59.364  18.018 2019-01-01 11:59:46    3.28
# 127101      16153       SDS011  55.648  13.208 2019-01-01 11:57:19   20.00
# 127102      16296       SDS011  56.144  13.394 2019-01-01 11:59:59   23.86
# 127103      16533       SDS011  55.722  13.202 2019-01-01 11:56:55   18.05
# 127104      16723       SDS011  57.736  11.894 2019-01-01 11:58:57   16.47
# 127105      16815       SDS011  59.462  18.040 2019-01-01 11:59:36    2.67
# 127106      17235       SDS011  59.272  17.780 2019-01-01 11:59:41    4.69
# 127107      10588       SDS011  55.676  13.346 2019-01-01 11:57:12   14.08
# 127108      10647       SDS011  55.608  13.036 2019-01-01 11:58:42   23.42
#
#            p2
# 0        1.56
# 1       33.82
# 2        2.47
# 3        6.62
# 4        1.02
# 5        5.54
# 6        2.00
# 7        2.80
# 8        2.18
# 9        1.90
# 60000    0.40
# 60001    1.90
# 60002    1.70
# 60003    2.62
# 60004    1.94
# 60005    2.38
# 60006   13.48
# 60007    8.46
# 60008   20.16
# 60009    2.30
# 127099   3.67
# 127100   1.80
# 127101   3.90
# 127102   7.45
# 127103   4.33
# 127104   3.40
# 127105   1.97
# 127106   1.82
# 127107   3.68
# 127108   4.75

# %%
# now resample the data, such that the time values in between are filled in

# %%
middle_array_with_earlier_and_later_added_times['timestamp'] = pd.to_datetime( middle_array_with_earlier_and_later_added_times['timestamp'] )

# %%
middle_array_with_earlier_and_later_added_times = middle_array_with_earlier_and_later_added_times.set_index('timestamp')

# %%
middle_array_with_earlier_and_later_added_times.index
# Out:
# DatetimeIndex(['2018-12-31 11:57:22', '2018-12-31 11:58:44',
#                '2018-12-31 11:58:47', '2018-12-31 11:56:41',
#                '2018-12-31 11:57:42', '2018-12-31 11:57:52',
#                '2018-12-31 11:58:51', '2018-12-31 11:58:28',
#                '2018-12-31 11:57:18', '2018-12-31 11:57:22',
#                '2018-12-31 16:52:43', '2018-12-31 16:52:21',
#                '2018-12-31 16:51:17', '2018-12-31 16:51:03',
#                '2018-12-31 16:51:10', '2018-12-31 16:50:49',
#                '2018-12-31 16:51:35', '2018-12-31 16:51:51',
#                '2018-12-31 16:50:46', '2018-12-31 16:51:31',
#                '2019-01-01 11:59:41', '2019-01-01 11:59:46',
#                '2019-01-01 11:57:19', '2019-01-01 11:59:59',
#                '2019-01-01 11:56:55', '2019-01-01 11:58:57',
#                '2019-01-01 11:59:36', '2019-01-01 11:59:41',
#                '2019-01-01 11:57:12', '2019-01-01 11:58:42'],
#               dtype='datetime64[ns]', name='timestamp', freq=None)

# %%
middle_array_with_earlier_and_later_added_times__RESAMPLED_to_fill_blank_time_intervals = middle_array_with_earlier_and_later_added_times.resample("5Min").mean().bfill()

# %%
middle_array_with_earlier_and_later_added_times__RESAMPLED_to_fill_blank_time_intervals
# Out:
#                      sensor_id      lat      lon      p1     p2
# timestamp
# 2018-12-31 11:55:00     7925.5  58.8428  18.0392  52.516  5.991
# 2018-12-31 12:00:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:05:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:10:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:15:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:20:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:25:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:30:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:35:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:40:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:45:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:50:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 12:55:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:00:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:05:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:10:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:15:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:20:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:25:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:30:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:35:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:40:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:45:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:50:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 13:55:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 14:00:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 14:05:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 14:10:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 14:15:00    13592.7  58.3782  15.7462  15.282  5.534
# 2018-12-31 14:20:00    13592.7  58.3782  15.7462  15.282  5.534
# ...                        ...      ...      ...     ...    ...
# 2019-01-01 09:30:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 09:35:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 09:40:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 09:45:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 09:50:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 09:55:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:00:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:05:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:10:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:15:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:20:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:25:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:30:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:35:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:40:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:45:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:50:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 10:55:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:00:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:05:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:10:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:15:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:20:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:25:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:30:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:35:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:40:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:45:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:50:00    15015.7  57.2354  14.3866  14.716  3.677
# 2019-01-01 11:55:00    15015.7  57.2354  14.3866  14.716  3.677
#
# [289 rows x 5 columns]

# %%
# SIDE test : let's try doing the resampling on one column only

# %%
middle_array_with_earlier_and_later_added_times
# Out:
#         sensor_id sensor_namee     lat     lon           timestamp      p1  \
# 0            7273       SDS011  60.002  17.846 2018-12-31 11:57:22    3.43
# 1            7275       SDS011  57.720  11.888 2018-12-31 11:58:44  482.77
# 2            7277       SDS011  59.266  15.230 2018-12-31 11:58:47    5.48
# 3            7406       SDS011  56.964  24.128 2018-12-31 11:56:41   11.05
# 4            7428       SDS011  59.868  17.624 2018-12-31 11:57:42    1.78
# 5            7469       SDS011  56.944  24.142 2018-12-31 11:57:52    8.40
# 6            7597       SDS011  59.320  18.064 2018-12-31 11:58:51    3.68
# 7            8683       SDS011  59.744  18.206 2018-12-31 11:58:28    3.01
# 8            9411       SDS011  59.266  15.230 2018-12-31 11:57:18    3.44
# 9            9436       SDS011  59.334  18.034 2018-12-31 11:57:22    2.12
# 60000       12679       SDS011  59.384  17.874 2018-12-31 16:52:43    0.40
# 60001       12687       SDS011  59.388  17.798 2018-12-31 16:52:21    2.83
# 60002       12691       SDS011  57.636  18.304 2018-12-31 16:51:17    2.40
# 60003       12693       SDS011  58.190  12.720 2018-12-31 16:51:03    6.42
# 60004       14017       SDS011  59.376  18.010 2018-12-31 16:51:10    4.07
# 60005       14133       SDS011  59.364  18.018 2018-12-31 16:50:49    4.14
# 60006       14209       SDS011  56.070  12.698 2018-12-31 16:51:35   28.52
# 60007       14264       SDS011  57.654  11.880 2018-12-31 16:51:51   26.92
# 60008       14276       SDS011  57.346  12.150 2018-12-31 16:50:46   72.48
# 60009       14278       SDS011  59.374  18.010 2018-12-31 16:51:31    4.64
# 127099      13020       SDS011  57.722  11.948 2019-01-01 11:59:41   20.64
# 127100      16147       SDS011  59.364  18.018 2019-01-01 11:59:46    3.28
# 127101      16153       SDS011  55.648  13.208 2019-01-01 11:57:19   20.00
# 127102      16296       SDS011  56.144  13.394 2019-01-01 11:59:59   23.86
# 127103      16533       SDS011  55.722  13.202 2019-01-01 11:56:55   18.05
# 127104      16723       SDS011  57.736  11.894 2019-01-01 11:58:57   16.47
# 127105      16815       SDS011  59.462  18.040 2019-01-01 11:59:36    2.67
# 127106      17235       SDS011  59.272  17.780 2019-01-01 11:59:41    4.69
# 127107      10588       SDS011  55.676  13.346 2019-01-01 11:57:12   14.08
# 127108      10647       SDS011  55.608  13.036 2019-01-01 11:58:42   23.42
#
#            p2
# 0        1.56
# 1       33.82
# 2        2.47
# 3        6.62
# 4        1.02
# 5        5.54
# 6        2.00
# 7        2.80
# 8        2.18
# 9        1.90
# 60000    0.40
# 60001    1.90
# 60002    1.70
# 60003    2.62
# 60004    1.94
# 60005    2.38
# 60006   13.48
# 60007    8.46
# 60008   20.16
# 60009    2.30
# 127099   3.67
# 127100   1.80
# 127101   3.90
# 127102   7.45
# 127103   4.33
# 127104   3.40
# 127105   1.97
# 127106   1.82
# 127107   3.68
# 127108   4.75

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY = middle_array_with_earlier_and_later_added_times[ [ 'timestamp', 'p1'] ]
middle_array_with_earlier_and_later_added_times__P1_ONLY
# Out:
#                  timestamp      p1
# 0      2018-12-31 11:57:22    3.43
# 1      2018-12-31 11:58:44  482.77
# 2      2018-12-31 11:58:47    5.48
# 3      2018-12-31 11:56:41   11.05
# 4      2018-12-31 11:57:42    1.78
# 5      2018-12-31 11:57:52    8.40
# 6      2018-12-31 11:58:51    3.68
# 7      2018-12-31 11:58:28    3.01
# 8      2018-12-31 11:57:18    3.44
# 9      2018-12-31 11:57:22    2.12
# 60000  2018-12-31 16:52:43    0.40
# 60001  2018-12-31 16:52:21    2.83
# 60002  2018-12-31 16:51:17    2.40
# 60003  2018-12-31 16:51:03    6.42
# 60004  2018-12-31 16:51:10    4.07
# 60005  2018-12-31 16:50:49    4.14
# 60006  2018-12-31 16:51:35   28.52
# 60007  2018-12-31 16:51:51   26.92
# 60008  2018-12-31 16:50:46   72.48
# 60009  2018-12-31 16:51:31    4.64
# 127099 2019-01-01 11:59:41   20.64
# 127100 2019-01-01 11:59:46    3.28
# 127101 2019-01-01 11:57:19   20.00
# 127102 2019-01-01 11:59:59   23.86
# 127103 2019-01-01 11:56:55   18.05
# 127104 2019-01-01 11:58:57   16.47
# 127105 2019-01-01 11:59:36    2.67
# 127106 2019-01-01 11:59:41    4.69
# 127107 2019-01-01 11:57:12   14.08
# 127108 2019-01-01 11:58:42   23.42

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY['timestamp'] = pd.to_datetime( middle_array_with_earlier_and_later_added_times__P1_ONLY['timestamp'] )
# Out:
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY.set_index('timestamp')
# Out:
#                          p1
# timestamp
# 2018-12-31 11:57:22    3.43
# 2018-12-31 11:58:44  482.77
# 2018-12-31 11:58:47    5.48
# 2018-12-31 11:56:41   11.05
# 2018-12-31 11:57:42    1.78
# 2018-12-31 11:57:52    8.40
# 2018-12-31 11:58:51    3.68
# 2018-12-31 11:58:28    3.01
# 2018-12-31 11:57:18    3.44
# 2018-12-31 11:57:22    2.12
# 2018-12-31 16:52:43    0.40
# 2018-12-31 16:52:21    2.83
# 2018-12-31 16:51:17    2.40
# 2018-12-31 16:51:03    6.42
# 2018-12-31 16:51:10    4.07
# 2018-12-31 16:50:49    4.14
# 2018-12-31 16:51:35   28.52
# 2018-12-31 16:51:51   26.92
# 2018-12-31 16:50:46   72.48
# 2018-12-31 16:51:31    4.64
# 2019-01-01 11:59:41   20.64
# 2019-01-01 11:59:46    3.28
# 2019-01-01 11:57:19   20.00
# 2019-01-01 11:59:59   23.86
# 2019-01-01 11:56:55   18.05
# 2019-01-01 11:58:57   16.47
# 2019-01-01 11:59:36    2.67
# 2019-01-01 11:59:41    4.69
# 2019-01-01 11:57:12   14.08
# 2019-01-01 11:58:42   23.42

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY.resample("5Min")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-08496dfd569d> in <module>
# ----> 1 middle_array_with_earlier_and_later_added_times__P1_ONLY.resample("5Min")
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    7108                      axis=axis, kind=kind, loffset=loffset,
#    7109                      convention=convention,
# -> 7110                      base=base, key=on, level=level)
#    7111         return _maybe_process_deprecations(r,
#    7112                                            how=how,
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
#    1146     """ create a TimeGrouper and return our resampler """
#    1147     tg = TimeGrouper(**kwds)
# -> 1148     return tg._get_resampler(obj, kind=kind)
#    1149
#    1150
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1274         raise TypeError("Only valid with DatetimeIndex, "
#    1275                         "TimedeltaIndex or PeriodIndex, "
# -> 1276                         "but got an instance of %r" % type(ax).__name__)
#    1277
#    1278     def _get_grouper(self, obj, validate=True):
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Int64Index'

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY = middle_array_with_earlier_and_later_added_times__P1_ONLY.set_index("timestamp")

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY.shape
# Out:
# (30, 1)

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY__RESAMPLED  = middle_array_with_earlier_and_later_added_times__P1_ONLY.resample("5Min").mean().bfill()

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY__RESAMPLED.shape
# Out:
# (289, 1)

# %%
middle_array_with_earlier_and_later_added_times__P1_ONLY__RESAMPLED
# Out:
#                          p1
# timestamp
# 2018-12-31 11:55:00  52.516
# 2018-12-31 12:00:00  15.282
# 2018-12-31 12:05:00  15.282
# 2018-12-31 12:10:00  15.282
# 2018-12-31 12:15:00  15.282
# 2018-12-31 12:20:00  15.282
# 2018-12-31 12:25:00  15.282
# 2018-12-31 12:30:00  15.282
# 2018-12-31 12:35:00  15.282
# 2018-12-31 12:40:00  15.282
# 2018-12-31 12:45:00  15.282
# 2018-12-31 12:50:00  15.282
# 2018-12-31 12:55:00  15.282
# 2018-12-31 13:00:00  15.282
# 2018-12-31 13:05:00  15.282
# 2018-12-31 13:10:00  15.282
# 2018-12-31 13:15:00  15.282
# 2018-12-31 13:20:00  15.282
# 2018-12-31 13:25:00  15.282
# 2018-12-31 13:30:00  15.282
# 2018-12-31 13:35:00  15.282
# 2018-12-31 13:40:00  15.282
# 2018-12-31 13:45:00  15.282
# 2018-12-31 13:50:00  15.282
# 2018-12-31 13:55:00  15.282
# 2018-12-31 14:00:00  15.282
# 2018-12-31 14:05:00  15.282
# 2018-12-31 14:10:00  15.282
# 2018-12-31 14:15:00  15.282
# 2018-12-31 14:20:00  15.282
# ...                     ...
# 2019-01-01 09:30:00  14.716
# 2019-01-01 09:35:00  14.716
# 2019-01-01 09:40:00  14.716
# 2019-01-01 09:45:00  14.716
# 2019-01-01 09:50:00  14.716
# 2019-01-01 09:55:00  14.716
# 2019-01-01 10:00:00  14.716
# 2019-01-01 10:05:00  14.716
# 2019-01-01 10:10:00  14.716
# 2019-01-01 10:15:00  14.716
# 2019-01-01 10:20:00  14.716
# 2019-01-01 10:25:00  14.716
# 2019-01-01 10:30:00  14.716
# 2019-01-01 10:35:00  14.716
# 2019-01-01 10:40:00  14.716
# 2019-01-01 10:45:00  14.716
# 2019-01-01 10:50:00  14.716
# 2019-01-01 10:55:00  14.716
# 2019-01-01 11:00:00  14.716
# 2019-01-01 11:05:00  14.716
# 2019-01-01 11:10:00  14.716
# 2019-01-01 11:15:00  14.716
# 2019-01-01 11:20:00  14.716
# 2019-01-01 11:25:00  14.716
# 2019-01-01 11:30:00  14.716
# 2019-01-01 11:35:00  14.716
# 2019-01-01 11:40:00  14.716
# 2019-01-01 11:45:00  14.716
# 2019-01-01 11:50:00  14.716
# 2019-01-01 11:55:00  14.716
#
# [289 rows x 1 columns]

# %% [markdown]
# ### now let's RETRY working on the bigger dataframe

# %%
middle_array_with_earlier_and_later_added_times.dtypes
# Out:
# sensor_id         int64
# sensor_namee     object
# lat             float64
# lon             float64
# p1              float64
# p2              float64
# dtype: object

# %%
middle_array_with_earlier_and_later_added_times['timestamp'] = pd.to_datetime( middle_array_with_earlier_and_later_added_times['timestamp'] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-43b20902e388> in <module>
# ----> 1 middle_array_with_earlier_and_later_added_times['timestamp'] = pd.to_datetime( middle_array_with_earlier_and_later_added_times['timestamp'] )
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'

# %%
middle_array_with_earlier_and_later_added_times = middle_array_with_earlier_and_later_added_times.set_index('timestamp')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-e16e2fc84e7f> in <module>
# ----> 1 middle_array_with_earlier_and_later_added_times = middle_array_with_earlier_and_later_added_times.set_index('timestamp')
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'

# %%
middle_array_with_earlier_and_later_added_times__RESAMPLED = middle_array_with_earlier_and_later_added_times.resample("5Min")
