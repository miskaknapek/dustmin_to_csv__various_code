# %% [markdown]
# # Scratchpad :
# ## using Panda's built-in timeseries functionality

# %%
import pandas as pd
import numpy as np
import time

# %%
# for plotting
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
# parameters

# start_time = "2018-12-31 21:58:42"
end_time = "2019-01-01 11:58:42"
# generate this please
start_time = "?????"

time_frequency_for_periods__for_basic_data = "5T"
num_of_time_periods___for_basic_data = 24*20 # 24 hrs * 12 x 5 mins in each hour

# when generating time periods 
sampling_frequency = "3T"



# --- data urls 

curr_url = "????"
nordic_midnight_24_hrs_data__url = "/Users/miska/Documents/open_something/luftdaten/luftdaten_code/luftdaten__make_tabular_data__from_db_data/ld_NYE_midnight_24hrs_nordics_all_data_01.csv"
# nordic_midnight_24_hrs_data__url = "/home/miska/documents/opensomething/luftdaten/dustmin_to_csv__various_code/ld_NYE_midnight_24hrs_nordics_all_data_01.csv"


# set the current data source 
curr_url =nordic_midnight_24_hrs_data__url

# %%
#open data 

in_data = pd.read_csv( curr_url )
in_data.shape
# Out:
# (127109, 7)

# %%
# make sure the timestamps are timestamps
in_data['timestamp'] = pd.to_datetime( in_data['timestamp'] )

# %%
in_data = in_data.sort_values( by=['timestamp'] )

# %%
type( in_data['timestamp'][0] )
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# set timestamp as the index
in_data = in_data.set_index( 'timestamp' )

# %%
in_data = in_data.sort_index()

# %%
# quick datadump
in_data[:15]
# Out:
#                      sensor_id sensor_namee     lat     lon      p1     p2
# timestamp
# 2018-12-31 11:55:19      13012       SDS011  57.662  12.006    6.30   2.60
# 2018-12-31 11:56:37      18112       SDS011  57.478  11.978  174.80  15.13
# 2018-12-31 11:56:38      15067       SDS011  60.024  18.770    1.62   1.02
# 2018-12-31 11:56:39      11765       SDS011  55.716  13.244   33.95  13.40
# 2018-12-31 11:56:40      14811       SDS011  57.706  11.900   63.25  10.33
# 2018-12-31 11:56:40      10827       SDS011  59.334  13.512   11.45   6.00
# 2018-12-31 11:56:40      17538       SDS011  55.612  12.972   13.68   3.12
# 2018-12-31 11:56:41       7406       SDS011  56.964  24.128   11.05   6.62
# 2018-12-31 11:56:42      16155       SDS011  59.832  17.632    1.66   1.10
# 2018-12-31 11:56:43      11058       SDS011  59.272  15.220    2.99   1.46
# 2018-12-31 11:56:43      16533       SDS011  55.722  13.202   26.43  14.00
# 2018-12-31 11:56:43      14807       SDS011  57.718  12.034   55.02   8.75
# 2018-12-31 11:56:44      10924       SDS011  59.860  17.652    2.58   1.16
# 2018-12-31 11:56:45      10723       SDS011  59.298  18.052    4.90   2.76
# 2018-12-31 11:56:47      17923       SDS011  55.730  13.200   42.12  18.17

# %%
# now the time has been sorted, turn it into epoch time :)

# %%
unique_sensor_ids = in_data['sensor_id'].unique()
unique_sensor_ids.shape
# Out:
# (205,)

# %%
type( unique_sensor_ids )
# Out:
# numpy.ndarray

# %%
unique_sensor_ids = np.sort( unique_sensor_ids )

# %%
unique_sensor_ids
# Out:
# array([ 5321,  7273,  7275,  7277,  7406,  7426,  7428,  7469,  7499,
#         7597,  8683,  9344,  9368,  9411,  9436,  9743,  9797, 10216,
#        10234, 10250, 10281, 10430, 10588, 10647, 10719, 10721, 10723,
#        10803, 10823, 10825, 10827, 10843, 10914, 10922, 10924, 10926,
#        11002, 11004, 11006, 11058, 11060, 11232, 11374, 11376, 11378,
#        11380, 11384, 11402, 11404, 11445, 11543, 11546, 11548, 11550,
# 2019-01-01 23:54:04       7273       SDS011  60.002  17.846  2.90  1.22
# 2019-01-01 23:56:33       7273       SDS011  60.002  17.846  4.14  1.48
#
# [716 rows x 6 columns]

# %%
# let's try indexing by time

# %%
random_sensor_id_data.index
# Out:
# DatetimeIndex(['2018-12-31 11:57:22', '2018-12-31 11:59:50',
#                '2018-12-31 12:04:47', '2018-12-31 12:07:16',
#                '2018-12-31 12:09:44', '2018-12-31 12:12:13',
#                '2018-12-31 12:14:43', '2018-12-31 12:19:43',
#                '2018-12-31 12:22:12', '2018-12-31 12:24:40',
#                ...
#                '2019-01-01 23:31:30', '2019-01-01 23:33:59',
#                '2019-01-01 23:36:27', '2019-01-01 23:38:56',
#                '2019-01-01 23:41:33', '2019-01-01 23:46:33',
#                '2019-01-01 23:46:33', '2019-01-01 23:51:36',
#                '2019-01-01 23:54:04', '2019-01-01 23:56:33'],
#               dtype='datetime64[ns]', name='timestamp', length=716, freq=None)

# %%
random_sensor_id_data__p1_extract__to_plot = random_sensor_id_data[ '2018-12-31 23:00' : '2018-12-31 23:30' ]['p1']
random_sensor_id_data__p1_extract__to_plot
# Out:
# timestamp
# 2018-12-31 23:00:57    11.17
# 2018-12-31 23:03:28    11.88
# 2018-12-31 23:05:57    10.25
# 2018-12-31 23:10:54     8.57
# 2018-12-31 23:13:23    10.10
# 2018-12-31 23:15:53     8.38
# 2018-12-31 23:18:21     6.84
# 2018-12-31 23:20:50     9.78
# 2018-12-31 23:25:50     7.76
# 2018-12-31 23:28:18     8.76
# 2018-12-31 23:30:47    12.02
# Name: p1, dtype: float64

# %%
random_sensor_id_data__p1_extract__to_plot.resample("5Min").mean()
# Out:
# timestamp
# 2018-12-31 23:00:00    11.525
# 2018-12-31 23:05:00    10.250
# 2018-12-31 23:10:00     9.335
# 2018-12-31 23:15:00     7.610
# 2018-12-31 23:20:00     9.780
# 2018-12-31 23:25:00     8.260
# 2018-12-31 23:30:00    12.020
# Freq: 5T, Name: p1, dtype: float64

# %%
in_data_P1_extract = in_data['p1']

# %%
# %time in_data_P1_extract.resample("5Min").mean()
# Out:
# CPU times: user 8.17 ms, sys: 1.36 ms, total: 9.53 ms
# Wall time: 8.38 ms
# timestamp
# 2018-12-31 11:55:00    43.607981
# 2018-12-31 12:00:00    36.501223
# 2018-12-31 12:05:00    41.185160
# 2018-12-31 12:10:00    40.648746
# 2018-12-31 12:15:00    38.348072
# 2018-12-31 12:20:00    32.435612
# 2018-12-31 12:25:00    30.573365
# 2018-12-31 12:30:00    29.368457
# 2018-12-31 12:35:00    24.010333
# 2018-12-31 12:40:00    30.291815
# 2018-12-31 12:45:00    30.055081
# 2018-12-31 12:50:00    27.613863
# 2018-12-31 12:55:00    42.683171
# 2018-12-31 13:00:00    25.068576
# 2018-12-31 13:05:00    19.973451
# 2018-12-31 13:10:00    20.164650
# 2018-12-31 13:15:00    19.058286
# 2018-12-31 13:20:00    15.242091
# 2018-12-31 13:25:00    18.353488
# 2019-01-01 23:35:00     7273.0  60.002  17.846  4.240  1.165
# 2019-01-01 23:40:00     7273.0  60.002  17.846  3.350  1.150
# 2019-01-01 23:45:00     7273.0  60.002  17.846  2.880  1.100
# 2019-01-01 23:50:00     7273.0  60.002  17.846  3.195  1.170
# 2019-01-01 23:55:00     7273.0  60.002  17.846  4.140  1.480
#
# [433 rows x 5 columns]

# %%
row2 = in_data_extract_sensor_id_7273__resampled[:1]

# %%
row2
# Out:
#                      sensor_id     lat     lon     p1     p2
# timestamp
# 2018-12-31 11:55:00     7273.0  60.002  17.846  3.605  1.555

# %%
type( row2 )
# Out:
# pandas.core.frame.DataFrame

# %%
row2.columns
# Out:
# Index(['sensor_id', 'lat', 'lon', 'p1', 'p2'], dtype='object')

# %%
### let's make a data row, compatible with the luftdaten dataframe we've got

# %%
# WITH the sensor name ( sensor_namee )
## df_sml = pd.DataFrame( data = { 'timestamp' : "2018-12-30 11:55:00", 'sensor_id' : 7273.0, 'sensor_namee' : 'SDS011', 'lat' : 60.002, 'lon' : 17.846, 'p1' : 3.605, 'p2' : 1.555 }, index=[ pd.Timestamp("2018-12-30 11:55:00")] )

# WITH AN INDEX 
# df_sml = pd.DataFrame( data = { 'timestamp' : "2018-12-30 11:55:00", 'sensor_id' : 7273.0, 'lat' : 60.002, 'lon' : 17.846, 'p1' : 3.605, 'p2' : 1.555 }, index=[ pd.Timestamp("2018-12-30 11:55:00")] )

# without sensor_namee and index
df_sml = pd.DataFrame( data = { 'timestamp' : "2018-12-31 10:55:00", 'sensor_id' : np.NaN, 'lat' : np.NaN, 'lon' : np.NaN, 'p1' : np.NaN, 'p2' : np.NaN }, index=[ 'timestamp' ] )

# %%
df_sml.columns
# Out:
# Index(['timestamp', 'sensor_id', 'lat', 'lon', 'p1', 'p2'], dtype='object')

# %%
df_sml
# Out:
#                      timestamp  sensor_id  lat  lon  p1  p2
# timestamp  2018-12-31 10:55:00        NaN  NaN  NaN NaN NaN

# %%
df_sml['timestamp'] = pd.to_datetime( df_sml['timestamp'] )

# %%
df_sml
# Out:
#                     timestamp  sensor_id  lat  lon  p1  p2
# timestamp 2018-12-31 10:55:00        NaN  NaN  NaN NaN NaN

# %%
df_sml = df_sml.set_index( 'timestamp' )

# %%
df_sml
# Out:
#                      sensor_id  lat  lon  p1  p2
# timestamp
# 2018-12-31 10:55:00        NaN  NaN  NaN NaN NaN

# %%
df_sml.dtypes
# Out:
# sensor_id    float64
# lat          float64
# lon          float64
# p1           float64
# p2           float64
# dtype: object

# %%
df_sml.columns
# Out:
# Index(['sensor_id', 'lat', 'lon', 'p1', 'p2'], dtype='object')

# %%
in_data_extract_sensor_id_7273__resampled_02 = in_data_extract_sensor_id_7273__resampled.append( df_sml )

# %%
in_data_extract_sensor_id_7273__resampled_02
# Out:
#                      sensor_id     lat     lon     p1     p2
# timestamp
# 2018-12-31 11:55:00     7273.0  60.002  17.846  3.605  1.555
# 2018-12-31 12:00:00     7273.0  60.002  17.846  4.120  1.900
# 2019-01-01 19:05:00 - 3.07
# 2019-01-01 19:10:00 - 2.1550000000000002
# 2019-01-01 19:15:00 - 1.63
# 2019-01-01 19:20:00 - 1.78
# 2019-01-01 19:25:00 - 1.685
# 2019-01-01 19:30:00 - 0.82
# 2019-01-01 19:35:00 - 1.42
# 2019-01-01 19:40:00 - 1.41
# 2019-01-01 19:45:00 - 1.525
# 2019-01-01 19:50:00 - 2.06
# 2019-01-01 19:55:00 - 1.56
# 2019-01-01 20:00:00 - 1.075
# 2019-01-01 20:05:00 - 1.66
# 2019-01-01 20:10:00 - 1.46
# 2019-01-01 20:15:00 - 1.45
# 2019-01-01 20:20:00 - 1.95
# 2019-01-01 20:25:00 - 2.085
# 2019-01-01 20:30:00 - 1.19
# 2019-01-01 20:35:00 - nan
# 2019-01-01 20:40:00 - nan
# 2019-01-01 20:45:00 - nan
# 2019-01-01 20:50:00 - 0.84
# 2019-01-01 20:55:00 - 1.08
# 2019-01-01 21:00:00 - 0.99
# 2019-01-01 21:05:00 - 1.55
# 2019-01-01 21:10:00 - 1.33
# 2019-01-01 21:15:00 - 2.87
# 2019-01-01 21:20:00 - 2.795
# 2019-01-01 21:25:00 - 1.28
# 2019-01-01 21:30:00 - 1.4100000000000001
# 2019-01-01 21:35:00 - 2.125
# 2019-01-01 21:40:00 - 2.75
# 2019-01-01 21:45:00 - 2.71
# 2019-01-01 21:50:00 - 2.49
# 2019-01-01 21:55:00 - 2.72
# 2019-01-01 22:00:00 - 2.76
# 2019-01-01 22:05:00 - 2.7199999999999998
# 2019-01-01 22:10:00 - 3.3
# 2019-01-01 22:15:00 - 3.0199999999999996
# 2019-01-01 22:20:00 - 2.645
# 2019-01-01 22:25:00 - 2.02
# 2019-01-01 22:30:00 - 1.62
# 2019-01-01 22:35:00 - 3.14
# 2019-01-01 22:40:00 - 4.04
# 2019-01-01 22:45:00 - 2.715
# 2019-01-01 22:50:00 - 3.8
# 2019-01-01 22:55:00 - 3.56
# 2019-01-01 23:00:00 - 3.37
# 2019-01-01 23:05:00 - 3.25
# 2019-01-01 23:10:00 - 3.18
# 2019-01-01 23:15:00 - 3.75
# 2019-01-01 23:20:00 - 3.6500000000000004
# 2019-01-01 23:25:00 - 5.98
# 2019-01-01 23:30:00 - 4.24
# 2019-01-01 23:35:00 - 4.24
# 2019-01-01 23:40:00 - 3.35
# 2019-01-01 23:45:00 - 2.88
# 2019-01-01 23:50:00 - 3.1950000000000003
# 2019-01-01 23:55:00 - 4.14

# %%
#### testing interpolation/resampling, and what effect having NaN values has one the resampled vlues 
#### that is - if one has a row with NaN values, in the same time period as is being resampled, how will that affect the values?

# %%
# first, let's prepare a few lines of data … to resample
in_data_sample = in_data[:3]
in_data_sample
# Out:
#                      sensor_id sensor_namee     lat     lon      p1     p2
# timestamp
# 2018-12-31 11:55:19      13012       SDS011  57.662  12.006    6.30   2.60
# 2018-12-31 11:56:37      18112       SDS011  57.478  11.978  174.80  15.13
# 2018-12-31 11:56:38      15067       SDS011  60.024  18.770    1.62   1.02

# %%
in_data_sample.loc[ :, 'sensor_id'] = 200
# Out:
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
in_data_sample
# Out:
#                      sensor_id sensor_namee     lat     lon      p1     p2
# timestamp
# 2018-12-31 11:55:19        200       SDS011  57.662  12.006    6.30   2.60
# 2018-12-31 11:56:37        200       SDS011  57.478  11.978  174.80  15.13
# 2018-12-31 11:56:38        200       SDS011  60.024  18.770    1.62   1.02

# %%
# set the other values too 
in_data_sample.loc[ :, 'lat'] = 200 
in_data_sample.loc[ :, 'lon'] = 200 
in_data_sample.loc[ :, 'p1'] = 200 
in_data_sample.loc[ :, 'p2'] = 200

# %%
in_data_sample
# Out:
#                      sensor_id sensor_namee  lat  lon   p1   p2
# timestamp
# 2018-12-31 11:55:19        200       SDS011  200  200  200  200
# 2018-12-31 11:56:37        200       SDS011  200  200  200  200
# 2018-12-31 11:56:38        200       SDS011  200  200  200  200

# %%
in_data_sample.loc[ 1:2, 'p1'] = np.NaN
in_data_sample.loc[ 1:2, 'p2'] = np.NaN

# %%
in_data_sample
# Out:
#                      sensor_id sensor_namee  lat  lon     p1     p2
# timestamp
# 2018-12-31 11:55:19        200       SDS011  200  200  200.0  200.0
# 2018-12-31 11:56:37        200       SDS011  200  200    NaN    NaN
# 2018-12-31 11:56:38        200       SDS011  200  200  200.0  200.0

# %%
# now let's try resampling 
in_data_sample__resampled = in_data_sample.resample( "5Min" ).mean()
in_data_sample__resampled
# Out:
#                      sensor_id  lat  lon     p1     p2
# timestamp
# 2018-12-31 11:55:00        200  200  200  200.0  200.0

# %%
# OK - this looks like the mean is not affected by the NAN values . 
# - LET'S TRY changing the p1 and p2 values a bit, to double-check that the averaging happens as I hope ( ie NaN values aren't included in the calculations )

# %%
in_data_sample_02 = in_data_sample
in_data_sample_02
# Out:
#                      sensor_id sensor_namee  lat  lon     p1     p2
# timestamp
# 2018-12-31 11:55:19        200       SDS011  200  200  200.0  200.0
# 2018-12-31 11:56:37        200       SDS011  200  200    NaN    NaN
# 2018-12-31 11:56:38        200       SDS011  200  200  200.0  200.0

# %%
in_data_sample_02.loc[ 2:3, 'p1'] = 100 
in_data_sample_02.loc[ 2:3, 'p2'] = 100

# %%
in_data_sample_02
# Out:
#                      sensor_id sensor_namee  lat  lon     p1     p2
# timestamp
# 2018-12-31 11:55:19        200       SDS011  200  200  200.0  200.0
# 2018-12-31 11:56:37        200       SDS011  200  200    NaN    NaN
# 2018-12-31 11:56:38        200       SDS011  200  200  100.0  100.0

# %%
# now let's try resampling - again
in_data_sample__resampled__02 = in_data_sample_02.resample( "5Min" ).mean()
in_data_sample__resampled__02
# Out:
#                      sensor_id  lat  lon     p1     p2
# timestamp
# 2018-12-31 11:55:00        200  200  200  150.0  150.0

# %% [markdown]
# ### testing making a in_data compatible row of data

# %%
# first test
in_data_row = pd.DataFrame( data={ 'one' : 1 }, index=[0] )

# %%
in_data_row
# Out:
#    one
# 0    1

# %%
# second test

# let's first get the column names
in_data.columns
# Out:
# Index(['sensor_id', 'sensor_namee', 'lat', 'lon', 'p1', 'p2'], dtype='object')

# %%
in_data_row = pd.DataFrame( data={ 'sensor_id' : np.NaN, 'sensor_namee' : 'SDS011', 'lat' : np.NaN, 'lon' : np.NaN, 'p1' : np.NaN, 'p2' : np.NaN, 'timestamp' : pd.to_datetime('2018-12-31 11:30:00') }, index=[0] )

# %%
in_data_row
# Out:
#    sensor_id sensor_namee  lat  lon  p1  p2           timestamp
# 0        NaN       SDS011  NaN  NaN NaN NaN 2018-12-31 11:30:00

# %%
in_data_row = in_data_row.set_index('timestamp')

# %%
in_data_row
# Out:
#                      sensor_id sensor_namee  lat  lon  p1  p2
# timestamp
# 2018-12-31 11:30:00        NaN       SDS011  NaN  NaN NaN NaN

# %% [markdown]
# #### now let's try appendign this to the in_data and see if it fits

# %%
in_data = in_data.set_index('timestamp')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-0b4c24e3975b> in <module>
# ----> 1 in_data = in_data.set_index('timestamp')
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'

# %%
in_data = in_data.sort_index()

# %%
in_data.head()
# Out:
#                      sensor_id sensor_namee     lat     lon      p1     p2
# timestamp
# 2018-12-31 11:55:19        200       SDS011  57.662  12.006    6.30   2.60
# 2018-12-31 11:56:37        200       SDS011  57.478  11.978  174.80  15.13
# 2018-12-31 11:56:38        200       SDS011  60.024  18.770    1.62   1.02
# 2018-12-31 11:56:39      11765       SDS011  55.716  13.244   33.95  13.40
# 2018-12-31 11:56:40      14811       SDS011  57.706  11.900   63.25  10.33

# %%
in_data = in_data.append( in_data_row )

# %%
in_data.tail()
# Out:
#                      sensor_id sensor_namee     lat     lon    p1    p2
# timestamp
# 2019-01-01 23:59:56    12129.0       SDS011  59.340  18.040  1.85  0.80
# 2019-01-01 23:59:56    12131.0       SDS011  59.450  17.916  1.48  0.52
# 2019-01-01 23:59:57    10843.0       SDS011  59.354  18.364  7.26  1.60
# 2019-01-01 23:59:58    11374.0       SDS011  59.258  18.008  2.65  2.01
# 2018-12-31 11:30:00        NaN       SDS011     NaN     NaN   NaN   NaN

# %%
in_data.iloc[-1]
# Out:
# sensor_id          NaN
# sensor_namee    SDS011
# lat                NaN
# lon                NaN
# p1                 NaN
# p2                 NaN
# Name: 2018-12-31 11:30:00, dtype: object

# %%
in_data['timestamp'] = in_data.index

# %%
in_data.index  = pd.to_datetime( in_data.index )

# %%
in_data = in_data.sort_index()

# %%
in_data.head()
# Out:
#                      sensor_id sensor_namee     lat     lon      p1     p2  \
# timestamp
# 2018-12-31 11:30:00        NaN       SDS011     NaN     NaN     NaN    NaN
# 2018-12-31 11:55:19      200.0       SDS011  57.662  12.006    6.30   2.60
# 2018-12-31 11:56:37      200.0       SDS011  57.478  11.978  174.80  15.13
# 2018-12-31 11:56:38      200.0       SDS011  60.024  18.770    1.62   1.02
# 2018-12-31 11:56:39    11765.0       SDS011  55.716  13.244   33.95  13.40
#
#                               timestamp
# timestamp
# 2018-12-31 11:30:00 2018-12-31 11:30:00
# 2018-12-31 11:55:19 2018-12-31 11:55:19
# 2018-12-31 11:56:37 2018-12-31 11:56:37
# 2018-12-31 11:56:38 2018-12-31 11:56:38
# 2018-12-31 11:56:39 2018-12-31 11:56:39

# %% [markdown]
# #### now try resampling

# %%
in_data__resampled = in_data.resample("5Min").mean()

# %%
in_data__resampled[:50]
# Out:
#                         sensor_id        lat        lon         p1         p2
# timestamp
# 2018-12-31 11:30:00           NaN        NaN        NaN        NaN        NaN
# 2018-12-31 11
# 2018-12-31 15:00:00  13792.453416  58.592416  15.490783  25.154752   5.624689
# 2018-12-31 15:05:00  13795.865169  58.564247  15.334292  28.345655   6.347491
# 2018-12-31 15:10:00  13801.920962  58.663423  15.705986  26.669519   5.525155
# 2018-12-31 15:15:00  13811.420561  58.525551  15.354785  29.646199   6.213894
# 2018-12-31 15:20:00  13949.280000  58.627869  15.321498  28.668000   7.701673
# 2018-12-31 15:25:00  13772.076923  58.629933  15.577030  32.814883   8.605920
# 2018-12-31 15:30:00  13714.451923  58.552256  15.346712  41.479776   9.438109
# 2018-12-31 15:35:00  13797.145390  58.519241  15.463993  35.026454   6.537163

# %%
#### replace NaN values using .where ( or something ) to 0
#### DOES NOTE WORK : replaces everyhing! 
# %time in_data__resampled.where( ['p1'] == 'NaN', 1 )
# in_data__resampled.where?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed eval> in <module>
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast, raise_on_error)
#    7770         other = com._apply_if_callable(other, self)
#    7771         return self._where(cond, other, inplace, axis, level,
# -> 7772                            errors=errors, try_cast=try_cast)
#    7773
#    7774     @Appender(_shared_docs['where'] % dict(_shared_doc_kwargs, cond="False",
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    7514                 cond = np.asanyarray(cond)
#    7515             if cond.shape != self.shape:
# -> 7516                 raise ValueError('Array conditional must be same shape as '
#    7517                                  'self')
#    7518             cond = self._constructor(cond, **self._construct_axes_dict())
#
# ValueError: Array conditional must be same shape as self

# %%
in_data__resampled
# Out:
#                         sensor_id        lat        lon         p1         p2
# timestamp
# 2018-12-31 11:30:00           NaN        NaN        NaN        NaN        NaN
# 2018-12-31 11:35:00           NaN        NaN        NaN        NaN        NaN
# 2018-12-31 11:40:00           NaN        NaN        NaN        NaN        NaN
# 2018-12-31 11:45:00           NaN        NaN        NaN        NaN        NaN
# 2018-12-31 11:50:00           NaN        NaN        NaN        NaN        NaN
# 2018-12-31 11:55:00  13683.305164  58.563502  15.409634  43.607981   5.800516
# 2018-12-31 12:00:00  13811.485893  58.645273  15.481956  36.501223   5.507429
# 2018-12-31 12:05:00  13656.868327  58.763566  15.535979  41.185160   5.515160
# 2018-12-31 12:10:00  13876.195122  58.584258  15.503247  40.648746   5.448467
# 2018-12-31 12:15:00  13773.369281  58.536327  15.256418  38.348072   5.651830
# 2018-12-31 12:20:00  13767.374101  58.675201  15.563568  32.435612   4.881187
# 2018-12-31 12:25:00  13893.840376  58.567158  15.448119  30.573365   4.793678
# 2018-12-31 12:30:00  13771.282958  58.572399  15.402540  29.368457   4.802862
# 2018-12-31 12:35:00  13819.111111  58.789681  15.629548  24.010333   4.093407
# 2018-12-31 12:40:00  13822.102740  58.488918  15.402274  30.291815   4.872158
# 2018-12-31 12:45:00  13782.915858  58.613307  15.485612  30.055081   4.607314
# 2018-12-31 12:50:00  13816.061372  58.717581  15.597227  27.613863   4.190866
# 2018-12-31 12:55:00  13941.599303  58.500941  15.292488  42.683171  12.579233
# 2018-12-31 13:00:00  13766.132911  58.573335  15.478797  25.068576   5.254051
# 2018-12-31 13:05:00  13968.549296  58.689197  15.677690  19.973451   4.140599
# 2018-12-31 13:10:00  13849.814685  58.401434  15.267021  20.164650   4.550245
# 2018-12-31 13:15:00  13743.238095  58.626927  15.528717  19.058286   4.365524
# 2019-01-01 23:50:00  13884.096654  58.602364  15.470208   3.020372   1.003011
# 2019-01-01 23:55:00  13740.511628  58.590844  15.329953   2.798306   0.977475
#
# [438 rows x 5 columns]

# %% [markdown]
# ### just want to try change one row of data… to sort of prove that I can ; )

# %%
in_data__reloaded = pd.read_csv( curr_url )
in_data__reloaded.shape
# Out:
# (127109, 7)

# %%
# make sure the timestamps are timestamps
in_data__reloaded['timestamp'] = pd.to_datetime( in_data__reloaded['timestamp'] )

# %%
in_data__reloaded = in_data__reloaded.sort_index()

# %%
in_data__reloaded.head()
# Out:
#    sensor_id sensor_namee     lat     lon            timestamp      p1     p2
# 0       7273       SDS011  60.002  17.846  2018-12-31 11:57:22    3.43   1.56
# 1       7275       SDS011  57.720  11.888  2018-12-31 11:58:44  482.77  33.82
# 2       7277       SDS011  59.266  15.230  2018-12-31 11:58:47    5.48   2.47
# 3       7406       SDS011  56.964  24.128  2018-12-31 11:56:41   11.05   6.62
# 4       7428       SDS011  59.868  17.624  2018-12-31 11:57:42    1.78   1.02

# %% [markdown]
# #### now back to setting that the data …

# %%
single_row_of_data = in_data__reloaded.iloc[0]

# %%
single_row_of_data
# Out:
# sensor_id                      7273
# sensor_namee                 SDS011
# lat                          60.002
# lon                          17.846
# timestamp       2018-12-31 11:57:22
# p1                             3.43
# p2                             1.56
# Name: 0, dtype: object

# %%
type( single_row_of_data )
# Out:
# pandas.core.series.Series

# %%
single_row_of_data.at['p1'] = -2
single_row_of_data.at['p2'] = np.NaN
single_row_of_data.at['sensor_namee'] = "not_sensor_name"
single_row_of_data.at['sensor_id'] = -22222
single_row_of_data.at['timestamp'] = pd.to_datetime( '2018-12-31 1:23:45')

# %%
single_row_of_data
# Out:
# sensor_id                    -22222
# sensor_namee        not_sensor_name
# lat                          60.002
# lon                          17.846
# timestamp       2018-12-31 01:23:45
# p1                               -2
# p2                              NaN
# Name: 0, dtype: object

# %% [markdown]
# #### now let's RETRY this, when the in_data has the timestamp as an index

# %%
in_data_w_time_index = in_data__reloaded.set_index( 'timestamp' )
in_data_w_time_index.sort_index()
å.head()
# Out:
#                      sensor_id sensor_namee     lat     lon      p1     p2
# timestamp
# 2018-12-31 11:57:22       7273       SDS011  60.002  17.846    3.43   1.56
# 2018-12-31 11:58:44       7275       SDS011  57.720  11.888  482.77  33.82
# 2018-12-31 11:58:47       7277       SDS011  59.266  15.230    5.48   2.47
# 2018-12-31 11:56:41       7406       SDS011  56.964  24.128   11.05   6.62
# 2018-12-31 11:57:42       7428       SDS011  59.868  17.624    1.78   1.02

# %%
in_data__reloaded.shape
# Out:
# (127109, 7)

# %%
single_row_of_data__02 = in_data_w_time_index.iloc[0]
single_row_of_data__02
# Out:
# sensor_id         7273
# sensor_namee    SDS011
# lat             60.002
# lon             17.846
# p1                3.43
# p2                1.56
# Name: 2018-12-31 11:57:22, dtype: object

# %%
single_row_of_data__02.at['p1'] = 0
single_row_of_data__02.at['p2'] = np.NaN
single_row_of_data__02.at['lat'] = np.NaN
single_row_of_data__02.at['lon'] = np.NaN
single_row_of_data__02.at['sensor_namee'] = "not_sensor_name"
single_row_of_data__02.at['sensor_id'] = -22222
# single_row_of_data__02.at['timestamp'] = pd.to_datetime( '2018-12-31 1:23:45')
single_row_of_data__02
# Out:
# sensor_id                -22222
# sensor_namee    not_sensor_name
# lat                         NaN
# lon                         NaN
# p1                            0
# p2                          NaN
# Name: 2019-01-01 12:20:00, dtype: object

# %%
single_row_of_data__02.name
# Out:
# Timestamp('2019-01-01 12:20:00')

# %%
single_row_of_data__02.name = pd.to_datetime( '2018-12-31 10:23:45')

# %%
single_row_of_data__02
# Out:
# sensor_id                -22222
# sensor_namee    not_sensor_name
# lat                         NaN
# lon                         NaN
# p1                            0
# p2                          NaN
# Name: 2018-12-31 10:23:45, dtype: object

# %%
single_row_of_data__02__END_time = single_row_of_data__02

# %%
single_row_of_data__02__END_time.name = pd.to_datetime( '2019-01-01 12:20:00' )
single_row_of_data__02__END_time
# Out:
# sensor_id                -22222
# sensor_namee    not_sensor_name
# lat                         NaN
# lon                         NaN
# p1                            0
# p2                          NaN
# Name: 2019-01-01 12:20:00, dtype: object

# %%
in_data_w_time_index.shape
# Out:
# (127113, 6)

# %%
# now let's see if we append it to the in_data_w_time_indexa
in_data_w_time_index = in_data_w_time_index.append( single_row_of_data__02 )
in_data_w_time_index = in_data_w_time_index.append( single_row_of_data__02__END_time )
in_data_w_time_index = in_data_w_time_index.sort_index()
# and shorten things a little
in_data_w_time_index = in_data_w_time_index[:25]
in_data_w_time_index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-6eb09c3e465a> in <module>
#       2 in_data_w_time_index = in_data_w_time_index.append( single_row_of_data__02 )
#       3 in_data_w_time_index = in_data_w_time_index.append( single_row_of_data__02__END_time )
# ----> 4 in_data_w_time_index = in_data_w_time_index.sort_index()
#       5 # and shorten things a little
#       6 in_data_w_time_index = in_data_w_time_index[:25]
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, by)
#    4485
#    4486             indexer = nargsort(labels, kind=kind, ascending=ascending,
# -> 4487                                na_position=na_position)
#    4488
#    4489         baxis = self._get_block_manager_axis(axis)
#
# /Applications/z_extras/code/anaconda3/lib/python3.6/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position)
#     253         non_nans = non_nans[::-1]
#     254         non_nan_idx = non_nan_idx[::-1]
# --> 255     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     256     if not ascending:
#     257         indexer = indexer[::-1]
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__richcmp__()
#
# TypeError: Cannot compare type 'Timestamp' with type 'str'

# %%
in_data_w_time_index = in_data_w_time_index.resample("5Min").mean().ffill()
in_data_w_time_index
# Out:
#                      sensor_id       lat      lon       p1      p2
# timestamp
# 2018-12-31 11:55:00    14423.4  57.87168  14.8744  22.9604  6.2552

# %%
in_data_w_time_index['p1'] = in_data_w_time_index.where( in_data_w_time_index['p1'] == np.NaN, 0 )

# %%
in_data_w_time_index
# Out:
#                      sensor_id       lat      lon   p1      p2
# timestamp
# 2018-12-31 11:55:00    14423.4  57.87168  14.8744  0.0  6.2552

# %%
### numpy array exercise

np_arr = np.array([] )
np_arr.push
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-dc1305ccfad3> in <module>
#       2
#       3 np_arr = np.array([] )
# ----> 4 np_arr.push
#
# AttributeError: 'numpy.ndarray' object has no attribute 'push'

# %%
pd_series = pd.Series( [] )
pd_series = pd_series.append( pd.DataFrame([1,2,3]) )
pd_series = pd_series.append( pd.DataFrame([1,2,3]) )
pd_series
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  3.0
# 0  1.0
# 1  2.0
# 2  3.0
